# %% [markdown]
# # Homework 2
#
# ### Due Date: Friday, March 20
#
# ### Policy Gradient
#
# In this assignment, we will implement vanilla policy gradient algorithm (REINFORCE) covered in the lecture. You will work on i) a function approximator, ii) computing action, iii) collecting samples, iV) training the agent, V) plotting the resutls.
#
#
# ***Complete the missing operations and test your implemented algorithm on the Gym environment.***
#
# ***Software requirements:***
# - Python >= 3.6
# - Tensorflow version <= 1.15.3 (1.X version)
# - OpenAI Gym
#
# - Training the agent (policy) can take long time. It is recomended to start solving the problems earlier.
#
# - Save any plots you generated in this notebook. The grade will be given based on the plots you showed.

# %% [markdown]
# Make sure the packages you installed meet the requirements.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
import gym
gym.__version__
# Out:
# '0.18.0'

# %% [markdown]
# ## 1.1 Tensorflow Implementation
#
# We will be implementing policy gradient algorithm using Tensorflow 1.X., which simply updates the parameters of policy from obtaining gradient estimates. The core of policy gradient is to design a function approximator, computing actions, collecting samples, and training the policy. In the below cell, you are encouraged to fill in the components that are missing. ***Your tasks*** are
#
# 1. Complete the 'create_model' method to output the mean value for diagonal Guassian policy. Covariance is already defined in the model, so focus on creating neural network model.
#
# 2. Complete the 'action_op' method to calculate and return the actions for diagonal Gaussian policy. The applied action should be $\pi(s) = \pi_{\text{mean}}(s) + exp(logstd) * \mathcal{N}(0,1)$
#
# ***Hints***:
# - Some useful tensorflow classes and methods include: 'tf.exp', 'tf.random_normal'

# %% [markdown]
# ***IF you are using MAC, please run below box***

# %%
import os
# MAC user only
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import tensorflow as tf
import numpy as np
import os
import ipdb


class PolicyOpt(object):

    def __init__(self, env, linear=False, stochastic=True, hidden_size=32, nonlinearity=tf.nn.relu):
        """Instantiate the policy iteration class.

        This initializes the policy optimization with a set of trainable 
        parameters, and creates a tensorflow session.

        Attributes
        ----------
        env : gym.Env
            the environment that the policy will be trained on
        linear : bool, optional
            specifies whether to use a linear or neural network 
            policy, defaults to False (i.e. Fully-Connected-Neural-Network)
        stochastic : bool, optional
            specifies whether to use a stochastic or deterministic 
            policy, defaults to True
        hidden_size : list of int, optional
            list of hidden layers, with each value corresponding 
            to the number of nodes in that layer 
        nonlinearity : tf.nn.*
            activation nonlinearity
        """
        
        # clear computation graph
        tf.reset_default_graph()
        
        # set a random seed
        tf.set_random_seed(1234)
        
        # start a tensorflow session
        self.sess = tf.Session()
        
        # environment to train on
        self.env = env
        
        print("_____test-----")
        print(self.env)
        print("_____test-----")
        
        # number of elements in the action space
        print("printing output space")
        self.ac_dim = env.action_space.shape[0]
        print("printing output space")
        print(self.ac_dim)
        print("printing output space end")
        
        # number of elements in the observation space
        self.obs_dim = env.observation_space.shape[0]

        # actions placeholder
        self.a_t_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.ac_dim])
        # state placeholder
        self.s_t_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.obs_dim])
        # expected reward placeholder
        self.rew_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None])

        # specifies whether the policy is stochastic
        self.stochastic = stochastic

        # policy that the agent executes during training/testing
        self.policy = self.create_model(
            args={
                "num_actions": self.ac_dim,
                "hidden_size": hidden_size,
                "linear": linear,
                "nonlinearity": nonlinearity,
                "stochastic": stochastic,
                "scope": "policy",
            }
        )
        
        # define symbolic action
        self.symbolic_action = self.action_op()

        # initialize all variables
        self.sess.run(tf.global_variables_initializer())

        # create saver to save model variables
        self.saver = tf.train.Saver()

    def create_model(self, args):
        """Create a model for your policy or other components.

        Parameters
        ----------
        args : dict
            model-specific arguments, with keys:
              - "stochastic": True by default
              - "hidden_size": Number of neurons in hidden layer
              - "num_actions" number of output actions
              - "scope": scope of the model

        Returns
        -------
        tf.Variable
            mean actions of the policy
        tf.Variable 
            logstd of the policy actions
        """

#################### Build Your Neural Network Here! ####################        
        h_layer1=tf.layers.dense(self.s_t_ph, args["hidden_size"], activation=args["nonlinearity"])
        h_layer2=tf.layers.dense(h_layer1, 16, activation=tf.keras.activations.tanh)
        output_mean= tf.layers.dense(h_layer2, args["num_actions"])
        print(output_mean)
##########################################################################        

        if args["stochastic"]:
            output_logstd =  tf.get_variable(name="action_logstd",shape=[self.ac_dim],trainable=True)
        else:
            output_logstd = None

        return output_mean, output_logstd
    
    def action_op(self):
        """
        Create a symbolic expression that will be used to compute actions from observations.

        When the policy is stochastic, the action follows 

            a_t = output_mean + exp(output_logstd) * z; z ~ N(0,1)
        """
        if self.stochastic:
            output_mean, output_logstd = self.policy

            #################### Implement a stochastic policy here ####################        
            # Implement a stochastic version of computing actions.       #
            #                                                            #
            # The action in a stochastic policy represented by           #
            # a diagonal Gaussian distribution with mean "M" and log     #
            # standard deviation "logstd" is computed as follows:        #
            #                                                            #
            #     a = M + exp(logstd) * z                                #
            #                                                            #
            # where z is a random normal value, i.e. z ~ N(0,1)          #
            #                                                            #
            # In order to generate numbers from a normal distribution,   #
            # use the `tf.random_normal` function.                       #
            ############################################################################ 
            symbolic_action = output_mean + tf.math.exp(output_logstd)*tf.random_normal([1])
            
        else:
            symbolic_action, _ = self.policy
        
        return symbolic_action

    def compute_action(self, obs):
        """Returns a list of actions for a given observation.

        Parameters
        ----------
        obs : np.ndarray
            observations

        Returns
        -------
        np.ndarray
            actions by the policy for a given observation
        """
        return self.sess.run(self.symbolic_action,feed_dict={self.s_t_ph: obs})

    def rollout(self, s_mean=None, s_std=None):
        """Collect samples from one rollout of the policy.

        Returns
        -------
        dict
            dictionary containing trajectory information for the rollout,
            specifically containing keys for "state", "action", "next_state", "reward", and "done"
        """
        states = []
        next_states = []
        actions = []
        rewards = []
        dones = []

        # start a new rollout by re-setting the environment and collecting the initial state
        state =  self.env.reset()

        steps = 0
        while True:
            steps += 1

            # compute the action given the state
            if s_mean is not None and s_std is not None:
                action = self.compute_action([(state - s_mean) / s_std])
            else:
                action = self.compute_action([state])
            action = action[0]

            # advance the environment once and collect the next state, reward, done, and info parameters from the environment
            next_state, reward, done, info =  self.env.step(action)

            # add to the samples list
            states.append(state)
            actions.append(action)
            next_states.append(next_state)
            rewards.append(reward)
            dones.append(done)

            state = next_state

            # if the environment returns a True for the done parameter,
            # end the rollout before the time horizon is met
            if done or steps > env._max_episode_steps:
                break

        # create the output trajectory
        trajectory = {"state": np.array(states, dtype=np.float32),
                      "reward": np.array(rewards, dtype=np.float32),
                      "action": np.array(actions, dtype=np.float32),
                      "next_state": np.array(next_states, dtype=np.float32),
                      "done": np.array(dones, dtype=np.float32)}

        return trajectory

    def train(self, args):
        """Abstract training method.

        This method will be filled in by algorithm-specific
        training operations in subsequent problems.

        Parameters
        ----------
        args : dict
            algorithm-specific hyperparameters
        """
        raise NotImplementedError

# %% [markdown]
# ## 1.2 Tensorflow Interpretation
#
# In order to test your implementation of the **stochastic policy**, run the below cell. The task is to interpret the code you implemented in previous section. If you implement correctly, you can see the value_1 and value_2.
#
# ***Question: How do you interpret value_1 and value_2 below cell?***

# %%
import gym
TEST_ENV = gym.make("Pendulum-v0")

alg = PolicyOpt(TEST_ENV, linear=False)
input_1 = [[0, 1, 2]]
value_1 = alg.sess.run(alg.policy[1], feed_dict={alg.s_t_ph: input_1})
value_2 = alg.compute_action(input_1)
# Out:
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)

# %%
TEST_ENV.env.action_space
# Out:
# Box(-2.0, 2.0, (1,), float32)

# %% [markdown]
# Answer:

# %%
value_2
# Out:
# array([[-0.46187037]], dtype=float32)

# %% [markdown]
# Answer:

# %% [markdown]
# ## 1.3 Implement Policy Gradient
#
# In this section, we will implement REINFORCE algorithm presented in the lecture. As a review, the objective is optimize the parameters $\theta$ of some policy $\pi_\theta$ so that the expected return
#
# \begin{equation}
# J(\theta) = \mathbb{E} \bigg\{ \sum_{t=0}^T \gamma^t r(s_{t},a_{t}) \bigg\}
# \end{equation}
#
# is optimized. In this algorithm, this is done by calculating the gradient $\nabla_\theta J$ and applying a gradient descent method to find a better policy.
#
# \begin{equation}
# \theta ' = \theta + \alpha \nabla_\theta J(\theta)
# \end{equation}
#
# In the lecture, we derive how we compute $\nabla_{\theta} J(\theta)$. We can rewrite our policy gradient as:
#
# \begin{equation}
# \nabla_\theta J (\theta) \approx \frac{1}{N} \sum_{i=0}^{N} \bigg( \sum_{t=0}^{T} \nabla_\theta \log \pi_\theta (a_{it} | s_{it}) \bigg) \bigg( \sum_{t=0}^T \gamma^{t}r_i(t) \bigg)
# \end{equation}
#
# Finally, taking into account the causality principle discussed in class, we are able to simplifiy the gradient estimate such as:
#
# \begin{equation}
# \nabla_\theta J (\theta) \approx \frac{1}{N} \sum_{i=0}^{N} \sum_{t=0}^{T} \nabla_\theta \log \pi_\theta (a_{it} | s_{it}) \sum_{t'=t}^T \gamma^{t'-t}r_i(t')
# \end{equation}
#
# You will be implementing final expression in this assignment!

# %% [markdown]
# The process of REINFOCE algorithm follows:
#
# 1. Collect samples from current policy $\pi_\theta(s)$ by executing rollouts of the environment.
# 2. Calculate an estimate for the expected return at state $s_t$.
# 3. Compute the log-likelihood of each action that was performed by the policy at every given step.
# 4. Estimate the gradient and update the parameters of policy using gradient-based technique.
# 5. Repeat steps 1-4 for a number of training iterations.
#
# ***Your task*** is to fill out the skeleton code for REINFORCE algorithm,
#
# 1. Complete the 'log_likelihoods' method to compute gradient of policy, $\nabla_{\theta}\pi_{\theta}$ for diagonal Guassian policy.
#
# 2. Complete the 'compute_expected_return' method to calculate the reward-to-go, $\sum_{t^{\prime}=t}^{T}$.

# %%
import tensorflow as tf
import numpy as np
import time
import tensorflow_probability as tfp

class REINFORCE(PolicyOpt):

    def train(self, num_iterations=1000, steps_per_iteration=1000, learning_rate=int(1e-4), gamma=0.95, 
              **kwargs):
        """Perform the REINFORE training operation.

        Parameters
        ----------
        num_iterations : int
            number of training iterations
        steps_per_iteration : int
            number of individual samples collected every training iteration
        learning_rate : float
            optimizer learning rate
        gamma : float
            discount rate
        kwargs : dict
            additional arguments

        Returns
        -------
        list of float
            average return per iteration
        """
        # set the discount as an attribute
        self.gamma = gamma
        
        # set the learning rate as an attribute
        self.learning_rate = learning_rate

        # create a symbolic expression to compute the log-likelihoods  
        log_likelihoods = self.log_likelihoods()

        # create a symbolic expression for updating the parameters of your policy
        self.opt, self.opt_baseline = self.define_updates(log_likelihoods)
        
        # initialize all variables
        self.sess.run(tf.global_variables_initializer())


        # average return per training iteration
        ret_per_iteration = []
        
        samples = []
        for i in range(num_iterations):
            
            # collect samples from the current policy
            samples.clear()
            steps_so_far = 0
            while steps_so_far < steps_per_iteration:
                new_samples = self.rollout()
                steps_so_far += new_samples["action"].shape[0]
                samples.append(new_samples)

            # compute the expected returns
            v_s = self.compute_expected_return(samples)

            # compute and apply the gradients
            self.call_updates(log_likelihoods, samples, v_s, **kwargs)

            # compute the average cumulative return per iteration
            average_rew = np.mean([sum(s["reward"]) for s in samples])

            # display iteration statistics
            print("Iteration {} return: {}".format(i, average_rew))
            ret_per_iteration.append(average_rew)

        return ret_per_iteration

    def log_likelihoods(self):
        """Create a tensorflow operation that computes the log-likelihood 
        of each performed action.
        """
        
        output_mean, output_logstd = self.policy

        ##############################################################
        # Create a tf operation to compute the log-likelihood of     #
        # each action that was performed by the policy               #
        #                                                            #
        # The log likelihood in the continuous case where the policy #
        # is expressed by a multivariate gaussian can be computing   #
        # using the tensorflow object:                               #
        #                                                            #
        #    p = tfp.distributions.MultivariateNormalDiag(           #
        #        loc=...,                                            #
        #        scale_diag=...,                                     #
        #    )                                                       #
        #                                                            #
        # This method takes as input a mean (loc) and standard       #
        # deviation (scale_diag), and then can be used to compute    #
        # the log-likelihood of a variable as follows:               #
        #                                                            #
        #    log_likelihoods = p.log_prob(...)                       #
        #                                                            #
        # For this operation, you will want to use placeholders      #
        # created in the __init__ method of problem 1.               #
        ##############################################################

        p = tfp.distributions.MultivariateNormalDiag(
                loc=output_mean, scale_diag=output_logstd)
        log_likelihoods = p.log_prob(self.a_t_ph)
        

        return log_likelihoods

    def compute_expected_return(self, samples):
        """Compute the expected return from a given starting state.
        This is done by using the reward-to-go method.

        Parameters
        ----------
        rewards : list of list of float
            a list of N trajectories, with each trajectory contain T 
            returns values (one for each step in the trajectory)

        Returns
        -------
        list of float, or np.ndarray
            expected returns for each step in each trajectory
        """
        rewards = [s["reward"] for s in samples]

        ##############################################################
        # State-Value Function                                       #
        #                                                            #
        # Estimate the expected return from any given starting state #
        # using the reward-to-go method.                             #
        #                                                            #
        # Using this method, the reward is estimated at every step   #
        # of the trajectory as follows:                              #
        #                                                            #
        #   r = sum_{t'=t}^T gamma^(t'-t) * r_{t'}                   #
        #                                                            #
        # where T is the time horizon at t is the index of the       #
        # current reward in the trajectory. For example, for a given #
        # set of rewards r = [1,1,1,1] and discount rate gamma = 1,  #
        # the expected reward-to-go would be:                        #
        #                                                            #
        #   v_s = [4, 3, 2, 1]                                       #
        #                                                            #
        # You will be able to test this in one of the cells below!   #
        ##############################################################
        v_s = []
        for r in rewards:
            for i in range(len(r)):
                v_s.append(sum(r[i:])*pow(self.gamma,(len(rewards)-i)))
                
#         v_s = [sum(r[i:])*pow(self.gamma,(len(rewards)-i))
#                   for r in rewards 
#                       for i in range(len(r))]
    
#         print(v_s.shape)
       
        return v_s

    def define_updates(self, log_likelihoods):
        """Create a tensorflow operation to update the parameters of 
        your policy.

        Parameters
        ----------
        log_likelihoods : tf.Operation
            the symbolic expression you created to estimate the log 
            likelihood of a set of actions

        Returns
        -------
        tf.Operation
            a tensorflow operation for computing and applying the 
            gradients to the parameters of the policy
        None
            the second component is used in problem 2.b, please ignore 
            for this problem
        """

        loss = - tf.reduce_mean(tf.multiply(log_likelihoods, self.rew_ph))
        opt = tf.train.AdamOptimizer(self.learning_rate).minimize(loss)

        return opt, None

    def call_updates(self, log_likelihoods, samples, v_s, **kwargs):
        """Apply the gradient update methods in a tensorflow session.

        Parameters
        ----------
        log_likelihoods: tf.Operation
            the symbolic expression you created to estimate the log 
            likelihood of a set of actions
        samples : list of dict
            a list of N trajectories, with each trajectory containing 
            a dictionary of trajectory data (see self.rollout)
        v_s : list of float, or np.ndarray
            the estimated expected returns from your
            `comput_expected_return` function 
        kwargs : dict
            additional arguments (used in question 3)
        """
        # concatenate the states
        states = np.concatenate([s["state"] for s in samples])

        # concatenate the actions
        actions = np.concatenate([s["action"] for s in samples])
        
#         print("Shape: "+v_s.shape)

        # execute the optimization step
        self.sess.run(self.opt, feed_dict={self.s_t_ph: states,
                                           self.a_t_ph: actions,
                                           self.rew_ph: v_s})

# %% [markdown]
# Check your 'log_likelihoods' method by running below cell:

# %%
alg = REINFORCE(TEST_ENV, stochastic=True)

log_likelihoods = alg.log_likelihoods()

# collect a sample output for a given input state
input_s = [[0, 0, 0], [0, 1, 2], [1, 2, 3]]
input_a = [[0], [1], [2]]

# Check
computed = alg.sess.run(log_likelihoods, feed_dict={alg.a_t_ph: input_a, alg.s_t_ph: input_s})
# Out:
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)

# %% [markdown]
# Test your 'compute_expected_return' by running below cell:

# %%
# 1. Test the non-normalized case
alg = REINFORCE(TEST_ENV, stochastic=True)
alg.gamma = 1.0
    
input_1 = [{"reward": [1, 1, 1, 1]},
           {"reward": [1, 1, 1, 1]}]
vs_1 = alg.compute_expected_return(samples=input_1)
ans_1 = np.array([4, 3, 2, 1, 4, 3, 2, 1])

if np.linalg.norm(vs_1 - ans_1) < 1e-3:
    print('Great job!')
else:
    print('Check your implementation (compute_expected_return)')
# Out:
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)
# Great job!

# %% [markdown]
# ## 1.4 Testing your algorithm
#
# When you are ready, test your policy gradient algorithms on the *Pendulum-v0* environment in the cell below. *Pendulum-v0* environment is similar to *off-shore wind power*, the goal here is to maintain the Pendulum is upright using control input. The best policy should get around -200 scores. ***Your task*** is to run your REINFORCE algorithm and plot the result!

# %%
# set this number as 1 for testing your algorithm, and 3 for plotting
NUM_TRIALS = 3

# ===========================================================================
# Do not modify below line
# ===========================================================================

# we will test the algorithms on the Pendulum-v0 gym environment
import gym
env = gym.make("Pendulum-v0")

# train on the REINFORCE algorithm
import numpy as np
r = []
for i in range(NUM_TRIALS):
    print("\n==== Training Run {} ====".format(i))
    alg = REINFORCE(env, stochastic=True)
    res = alg.train(learning_rate=0.005, gamma=0.95, num_iterations=500, steps_per_iteration=15000)
    r.append(np.array(res))
    alg = None

# save results
np.savetxt("InvertedPendulum_results.csv", np.array(r), delimiter=",")
# Out:
# ==== Training Run 0 ====
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)
# Iteration 0 return: -1180.8859012087642
# Iteration 1 return: -1224.7085585666416
# Iteration 2 return: -1191.3268972436006
# Iteration 3 return: -1184.8050718387153
# Iteration 4 return: -1214.8788003548484
# Iteration 5 return: -1133.0621657521247
# Iteration 6 return: -1112.8884323031114
# Iteration 7 return: -1176.2947432867127
# Iteration 8 return: -1143.5918119300716
# Iteration 9 return: -1115.1254841192733
# Iteration 10 return: -1093.0886835390236
# Iteration 11 return: -1161.76841530172
# Iteration 12 return: -1137.3320088541275
# Iteration 13 return: -1136.410112428867
# Iteration 14 return: -1148.3590880615955
# Iteration 15 return: -1154.5878351936271
# Iteration 16 return: -1127.6179562043762
# Iteration 17 return: -1106.1796170743137
# Iteration 18 return: -1160.2065365585436
# Iteration 19 return: -1173.4044757887395
# Iteration 20 return: -1166.1355093010764
# Iteration 21 return: -1204.5892783992986
# Iteration 22 return: -1185.5989247353407
# Iteration 23 return: -1185.819790534797
# Iteration 24 return: -1186.5185572073826
# Iteration 25 return: -1171.4115017300285
# Iteration 26 return: -1188.1011364080632
# Iteration 27 return: -1188.7207595235761
# Iteration 28 return: -1147.75495941688
# Iteration 29 return: -1200.613576310845
# Iteration 30 return: -1126.0210909085317
# Iteration 31 return: -1099.978755022868
# Iteration 32 return: -1135.3696830369718
# Iteration 33 return: -1090.4688705425042
# Iteration 34 return: -1088.0212728116132
# Iteration 35 return: -1120.5286934941246
# Iteration 36 return: -1088.4455581248085
# Iteration 37 return: -1095.0367965001954
# Iteration 38 return: -1119.4236392409362
# Iteration 39 return: -1098.3458463556412
# Iteration 40 return: -1099.5108570348348
# Iteration 41 return: -1059.1936167618228
# Iteration 42 return: -1097.6153889611153
# Iteration 43 return: -1082.4791792784943
# Iteration 44 return: -1096.815177078206
# Iteration 45 return: -1064.4942633164364
# Iteration 46 return: -1086.120602914871
# Iteration 47 return: -1128.6369295452255
# Iteration 48 return: -1070.9074841311449
# Iteration 49 return: -1100.3274906762626
# Iteration 50 return: -1083.4510602495882
# Iteration 51 return: -1062.1849091824827
# Iteration 52 return: -1067.3835855606198
# Iteration 53 return: -1074.660920284583
# Iteration 54 return: -1081.3099279879468
# Iteration 55 return: -1070.4926033003069
# Iteration 56 return: -1069.3942367920124
# Iteration 57 return: -1047.530846969001
# Iteration 58 return: -1078.349789110641
# Iteration 59 return: -1031.435247402753
# Iteration 60 return: -1078.4188644462731
# Iteration 61 return: -1056.5466743374407
# Iteration 62 return: -1008.9659119881223
# Iteration 63 return: -1040.3350114908062
# Iteration 64 return: -1021.345419122347
# Iteration 65 return: -1032.1397150795192
# Iteration 66 return: -1049.04841792399
# Iteration 67 return: -1023.3956202004198
# Iteration 68 return: -1028.202743784242
# Iteration 69 return: -1057.4122473615284
# Iteration 70 return: -1064.8679419015502
# Iteration 71 return: -1090.3191188692736
# Iteration 72 return: -1087.2255369299899
# Iteration 73 return: -1089.471867661268
# Iteration 74 return: -1120.9763068976874
# Iteration 75 return: -1104.0546137490217
# Iteration 76 return: -1064.624337711765
# Iteration 77 return: -1067.2648012939933
# Iteration 78 return: -1083.0580916002239
# Iteration 79 return: -1051.9343848138146
# Iteration 80 return: -1047.7400023279386
# Iteration 81 return: -1008.4404398978277
# Iteration 82 return: -993.4984119489222
# Iteration 83 return: -996.1060806395269
# Iteration 84 return: -1005.031771657827
# Iteration 85 return: -1033.7218778504619
# Iteration 86 return: -1009.4587960991666
# Iteration 87 return: -998.5027392524535
# Iteration 88 return: -1027.1843080010963
# Iteration 89 return: -970.6917633650157
# Iteration 90 return: -999.6061860765024
# Iteration 91 return: -978.4388559311939
# Iteration 92 return: -986.2654741439782
# Iteration 93 return: -997.9595517088969
# Iteration 94 return: -973.5125154007754
# Iteration 95 return: -1007.5844588770096
# Iteration 96 return: -973.4794046212888
# Iteration 97 return: -953.8180120029332
# Iteration 98 return: -967.273112707859
# Iteration 99 return: -940.0270260826499
# Iteration 100 return: -948.4758390797629
# Iteration 101 return: -950.9845838179315
# Iteration 102 return: -947.2232043646183
# Iteration 103 return: -939.1300068990816
# Iteration 104 return: -934.902385328856
# Iteration 105 return: -926.0071615342807
# Iteration 106 return: -947.6633968509594
# Iteration 107 return: -966.5156752538805
# Iteration 108 return: -986.160489192619
# Iteration 109 return: -1002.467428612827
# Iteration 110 return: -996.1602333645602
# Iteration 111 return: -989.7335947210341
# Iteration 112 return: -945.5134193717364
# Iteration 113 return: -905.6070311008879
# Iteration 114 return: -904.0422799231919
# Iteration 115 return: -921.1987967654348
# Iteration 116 return: -876.7528549129827
# Iteration 117 return: -874.7007321985963
# Iteration 118 return: -861.4488971728273
# Iteration 119 return: -887.6333558144979
# Iteration 120 return: -874.4153931692219
# Iteration 121 return: -884.8698414130555
# Iteration 122 return: -886.7028445507514
# Iteration 123 return: -870.7999078621838
# Iteration 124 return: -858.59807190713
# Iteration 125 return: -911.2844841664781
# Iteration 126 return: -945.5543893804122
# Iteration 127 return: -880.1261018370348
# Iteration 128 return: -879.8471905951993
# Iteration 129 return: -837.0574733663428
# Iteration 130 return: -885.9903587232685
# Iteration 131 return: -861.5130661877478
# Iteration 132 return: -873.610868582585
# Iteration 133 return: -861.6279311913215
# Iteration 134 return: -857.7879364106401
# Iteration 135 return: -850.0712181560974
# Iteration 136 return: -788.778965836543
# Iteration 137 return: -740.0288678860626
# Iteration 138 return: -730.4461768478911
# Iteration 139 return: -719.9652974234374
# Iteration 140 return: -689.1888758316477
# Iteration 141 return: -697.9227630361953
# Iteration 142 return: -776.9558398926786
# Iteration 143 return: -800.467593455067
# Iteration 144 return: -755.3891417113691
# Iteration 145 return: -621.6516983188617
# Iteration 146 return: -665.4416326337665
# Iteration 147 return: -652.6435009237265
# Iteration 148 return: -637.5907387123223
# Iteration 149 return: -668.6280448193794
# Iteration 150 return: -617.194586441221
# Iteration 151 return: -612.6931161323783
# Iteration 152 return: -606.5690663093717
# Iteration 153 return: -627.1514972366084
# Iteration 154 return: -641.6349681882931
# Iteration 155 return: -621.4029756929066
# Iteration 156 return: -563.8909425379742
# Iteration 157 return: -564.8952522890725
# Iteration 158 return: -562.569050667007
# Iteration 159 return: -529.8995015547774
# Iteration 160 return: -511.2522524168969
# Iteration 161 return: -458.5574665477753
# Iteration 162 return: -463.4767465209838
# Iteration 163 return: -370.315753364491
# Iteration 164 return: -353.7202785394086
# Iteration 165 return: -371.12448527605346
# Iteration 166 return: -344.7870961391932
# Iteration 167 return: -353.8547204894969
# Iteration 168 return: -300.98287925251947
# Iteration 169 return: -260.2141721845944
# Iteration 170 return: -300.7354446267606
# Iteration 171 return: -317.8679891933591
# Iteration 172 return: -276.6138493840089
# Iteration 173 return: -336.8046642742333
# Iteration 174 return: -306.9470182594256
# Iteration 175 return: -290.9802120722499
# Iteration 176 return: -299.6070639888379
# Iteration 177 return: -316.22931126765707
# Iteration 178 return: -258.25147749752813
# Iteration 179 return: -309.66594601489106
# Iteration 180 return: -315.247168620169
# Iteration 181 return: -360.4368574225993
# Iteration 182 return: -318.69879342587853
# Iteration 183 return: -286.0121796114609
# Iteration 184 return: -349.1139181776201
# Iteration 185 return: -316.20849000151685
# Iteration 186 return: -347.2794393262488
# Iteration 187 return: -352.059524534172
# Iteration 188 return: -364.60237213556877
# Iteration 189 return: -356.4710963862604
# Iteration 190 return: -376.806150398024
# Iteration 191 return: -367.2936402771889
# Iteration 192 return: -384.9615638599311
# Iteration 193 return: -393.71386374904404
# Iteration 194 return: -381.10373655617985
# Iteration 195 return: -368.03306786552264
# Iteration 196 return: -412.88513163052374
# Iteration 197 return: -316.6500180337176
# Iteration 198 return: -375.9444744387412
# Iteration 199 return: -400.87419781453315
# Iteration 200 return: -330.5596679181427
# Iteration 201 return: -375.400675636518
# Iteration 202 return: -330.48587906392726
# Iteration 203 return: -365.6719188295742
# Iteration 204 return: -342.3548415667756
# Iteration 205 return: -303.6929350370638
# Iteration 206 return: -307.5684817228231
# Iteration 207 return: -347.18154258821136
# Iteration 208 return: -287.1767814768019
# Iteration 209 return: -259.60632992775095
# Iteration 210 return: -279.0680878449393
# Iteration 211 return: -290.93445438408816
# Iteration 212 return: -271.3458554071541
# Iteration 213 return: -276.74194365220916
# Iteration 214 return: -294.5827203102717
# Iteration 215 return: -268.19837531449514
# Iteration 216 return: -294.18330955056996
# Iteration 217 return: -329.65214696064083
# Iteration 218 return: -268.29004653612964
# Iteration 219 return: -275.3371816304147
# Iteration 220 return: -238.38888015747324
# Iteration 221 return: -280.41406832322946
# Iteration 222 return: -269.3256063896782
# Iteration 223 return: -233.69742206502173
# Iteration 224 return: -297.18528937839625
# Iteration 225 return: -249.40610513783622
# Iteration 226 return: -298.939515560003
# Iteration 227 return: -273.9081991964592
# Iteration 228 return: -294.5687614935672
# Iteration 229 return: -268.9907287249069
# Iteration 230 return: -290.0024577691111
# Iteration 231 return: -247.6182124594255
# Iteration 232 return: -280.6367685113285
# Iteration 233 return: -279.8993715141987
# Iteration 234 return: -278.8817632827305
# Iteration 235 return: -289.26605321596054
# Iteration 236 return: -240.79433566948558
# Iteration 237 return: -253.67809999911472
# Iteration 238 return: -290.1096067318085
# Iteration 239 return: -294.40931299816407
# Iteration 240 return: -292.490015294528
# Iteration 241 return: -257.4546282191897
# Iteration 242 return: -278.5505364130631
# Iteration 243 return: -288.98546101249354
# Iteration 244 return: -312.86307178140555
# Iteration 245 return: -290.73224420713734
# Iteration 246 return: -305.01549616901104
# Iteration 247 return: -316.9081734377325
# Iteration 248 return: -212.88975019369232
# Iteration 249 return: -323.58962216525777
# Iteration 250 return: -257.76645269745643
# Iteration 251 return: -280.21347362043554
# Iteration 252 return: -280.0944999111138
# Iteration 253 return: -270.92939835294914
# Iteration 254 return: -275.3528309565162
# Iteration 255 return: -275.9343249908401
# Iteration 256 return: -281.4764038391132
# Iteration 257 return: -239.8270359608498
# Iteration 258 return: -252.8706532040803
# Iteration 259 return: -274.73227045214765
# Iteration 260 return: -247.92004061908617
# Iteration 261 return: -283.8388676378623
# Iteration 262 return: -261.31312890490034
# Iteration 263 return: -269.6155348993037
# Iteration 264 return: -295.20748792225095
# Iteration 265 return: -243.25081110197814
# Iteration 266 return: -254.2744254953208
# Iteration 267 return: -270.3958543420425
# Iteration 268 return: -284.5530065124826
# Iteration 269 return: -292.71050700634885
# Iteration 270 return: -320.17294651269435
# Iteration 271 return: -241.0814912429789
# Iteration 272 return: -288.55415756831593
# Iteration 273 return: -222.2084843269234
# Iteration 274 return: -253.47820221997813
# Iteration 275 return: -284.57661051188916
# Iteration 276 return: -293.86186954097326
# Iteration 277 return: -276.7385266837074
# Iteration 278 return: -287.4555506069074
# Iteration 279 return: -292.60616339447023
# Iteration 280 return: -262.7059255885201
# Iteration 281 return: -284.22552212472374
# Iteration 282 return: -265.39679178685486
# Iteration 283 return: -282.88709727756293
# Iteration 284 return: -284.8386816760956
# Iteration 285 return: -287.1073334171179
# Iteration 286 return: -266.86111729399505
# Iteration 287 return: -260.02913216096925
# Iteration 288 return: -288.3919408181069
# Iteration 289 return: -272.2797731234001
# Iteration 290 return: -292.7199285217086
# Iteration 291 return: -300.1145732979427
# Iteration 292 return: -276.03180445734165
# Iteration 293 return: -252.89869221554883
# Iteration 294 return: -257.51123126452825
# Iteration 295 return: -291.4951533571706
# Iteration 296 return: -219.50732367390756
# Iteration 297 return: -265.7649424009135
# Iteration 298 return: -267.8837232461975
# Iteration 299 return: -266.66395312378603
# Iteration 300 return: -264.823116715414
# Iteration 301 return: -301.7383889164486
# Iteration 302 return: -225.55266787407595
# Iteration 303 return: -232.2383774485419
# Iteration 304 return: -278.75534352807824
# Iteration 305 return: -258.23892280065036
# Iteration 306 return: -271.22709988821407
# Iteration 307 return: -255.07934060985954
# Iteration 308 return: -253.04743603400186
# Iteration 309 return: -258.0225711768469
# Iteration 310 return: -243.6540750607664
# Iteration 311 return: -267.6715605982485
# Iteration 312 return: -254.72480642408482
# Iteration 313 return: -239.45611129839915
# Iteration 314 return: -261.16247102211673
# Iteration 315 return: -246.65801908149336
# Iteration 316 return: -360.1903367662598
# Iteration 317 return: -249.08243237701865
# Iteration 318 return: -241.48561787564321
# Iteration 319 return: -275.83737453749114
# Iteration 320 return: -269.4245137798498
# Iteration 321 return: -269.4276351895533
# Iteration 322 return: -290.19838553794364
# Iteration 323 return: -269.4946335504541
# Iteration 324 return: -256.924510568658
# Iteration 325 return: -244.9051698855173
# Iteration 326 return: -258.3016150868619
# Iteration 327 return: -260.6852107299944
# Iteration 328 return: -253.94518748914987
# Iteration 329 return: -262.20953469262275
# Iteration 330 return: -255.80194406639868
# Iteration 331 return: -248.64875658120388
# Iteration 332 return: -258.01895559714353
# Iteration 333 return: -265.8442421112329
# Iteration 334 return: -271.2104624361482
# Iteration 335 return: -247.55669023659357
# Iteration 336 return: -267.1404217831549
# Iteration 337 return: -300.69236762988334
# Iteration 338 return: -268.33334037204366
# Iteration 339 return: -285.6240871608137
# Iteration 340 return: -239.75191590672398
# Iteration 341 return: -273.8847085688294
# Iteration 342 return: -248.77138356040547
# Iteration 343 return: -268.9584304440211
# Iteration 344 return: -254.43798320613024
# Iteration 345 return: -272.13674996035604
# Iteration 346 return: -299.834717738773
# Iteration 347 return: -286.860056057413
# Iteration 348 return: -290.1478056936723
# Iteration 349 return: -284.75905854813425
# Iteration 350 return: -271.96981464257374
# Iteration 351 return: -272.2205603193088
# Iteration 352 return: -252.69444871782082
# Iteration 353 return: -287.3373779947416
# Iteration 354 return: -266.4939575945874
# Iteration 355 return: -267.9307328189501
# Iteration 356 return: -278.7692110621493
# Iteration 357 return: -286.8197465749958
# Iteration 358 return: -274.5735656116178
# Iteration 359 return: -253.0429495428161
# Iteration 360 return: -268.1397967603319
# Iteration 361 return: -247.13313920005535
# Iteration 362 return: -247.6809734360062
# Iteration 363 return: -295.2571154987873
# Iteration 364 return: -251.6584244343342
# Iteration 365 return: -264.48911288980725
# Iteration 366 return: -268.089851782619
# Iteration 367 return: -261.3772973025717
# Iteration 368 return: -292.32862123941476
# Iteration 369 return: -252.43331838295234
# Iteration 370 return: -293.59102419203896
# Iteration 371 return: -221.53200151314076
# Iteration 372 return: -233.6661119491569
# Iteration 373 return: -237.03542657443566
# Iteration 374 return: -278.47333407259026
# Iteration 375 return: -250.66021300812528
# Iteration 376 return: -266.61123517859755
# Iteration 377 return: -283.4113717059564
# Iteration 378 return: -272.83195320109127
# Iteration 379 return: -219.04125891288155
# Iteration 380 return: -262.2801256529455
# Iteration 381 return: -258.85351542707804
# Iteration 382 return: -238.04346272373394
# Iteration 383 return: -249.728156321813
# Iteration 384 return: -290.1708433268377
# Iteration 385 return: -258.1606519348185
# Iteration 386 return: -258.46050907193734
# Iteration 387 return: -280.18044567870294
# Iteration 388 return: -286.457711887191
# Iteration 389 return: -254.09025493378704
# Iteration 390 return: -304.5078864613596
# Iteration 391 return: -307.5795847115464
# Iteration 392 return: -272.1908668530428
# Iteration 393 return: -265.8904083448855
# Iteration 394 return: -278.93870551969417
# Iteration 395 return: -279.9845958212239
# Iteration 396 return: -256.2533408336724
# Iteration 397 return: -259.1567148799994
# Iteration 398 return: -224.28033786873507
# Iteration 399 return: -254.148420912432
# Iteration 400 return: -267.9857945551494
# Iteration 401 return: -265.78683911114416
# Iteration 402 return: -229.8497525925786
# Iteration 403 return: -253.2806517269784
# Iteration 404 return: -236.02611731661023
# Iteration 405 return: -284.1192438045878
# Iteration 406 return: -250.63949894540167
# Iteration 407 return: -270.4242218435581
# Iteration 408 return: -234.45574712727844
# Iteration 409 return: -226.84321458831798
# Iteration 410 return: -258.3991986137263
# Iteration 411 return: -270.5247096624333
# Iteration 412 return: -261.4550683793229
# Iteration 413 return: -237.26489609503236
# Iteration 414 return: -267.3923719646999
# Iteration 415 return: -306.6187644643165
# Iteration 416 return: -275.2349725145817
# Iteration 417 return: -222.90142952190575
# Iteration 418 return: -214.75518830967476
# Iteration 419 return: -222.24202793059342
# Iteration 420 return: -259.6769521261707
# Iteration 421 return: -244.82559644830553
# Iteration 422 return: -266.86204359525516
# Iteration 423 return: -263.3258346567583
# Iteration 424 return: -267.96038452285563
# Iteration 425 return: -253.26533473701284
# Iteration 426 return: -253.21078086953864
# Iteration 427 return: -246.78148916041576
# Iteration 428 return: -252.61120222448378
# Iteration 429 return: -260.48319050875995
# Iteration 430 return: -253.11114823736978
# Iteration 431 return: -225.8572440894034
# Iteration 432 return: -241.1372086369062
# Iteration 433 return: -270.3243586498824
# Iteration 434 return: -262.4057461008901
# Iteration 435 return: -239.34427507582498
# Iteration 436 return: -279.58490294743206
# Iteration 437 return: -239.52351126992454
# Iteration 438 return: -239.08190020023133
# Iteration 439 return: -230.38377762701634
# Iteration 440 return: -239.41795429338362
# Iteration 441 return: -244.66249752739571
# Iteration 442 return: -259.8405569899455
# Iteration 443 return: -260.75171815243175
# Iteration 444 return: -210.31483268075493
# Iteration 445 return: -223.36274564413606
# Iteration 446 return: -218.224813285452
# Iteration 447 return: -249.6212866353841
# Iteration 448 return: -277.36792809477424
# Iteration 449 return: -236.53178907349977
# Iteration 450 return: -217.42704791477
# Iteration 451 return: -244.11099557511736
# Iteration 452 return: -244.4684678220003
# Iteration 453 return: -255.04919855392208
# Iteration 454 return: -251.42430908058222
# Iteration 455 return: -250.57225741100027
# Iteration 456 return: -263.5769617844269
# Iteration 457 return: -242.69188898630824
# Iteration 458 return: -244.2290320728522
# Iteration 459 return: -236.9204528404722
# Iteration 460 return: -263.2383435991545
# Iteration 461 return: -238.24026543299317
# Iteration 462 return: -261.56750465531854
# Iteration 463 return: -201.22148117577265
# Iteration 464 return: -244.4113508183463
# Iteration 465 return: -246.4329651566538
# Iteration 466 return: -270.2697286067776
# Iteration 467 return: -218.43732738404034
# Iteration 468 return: -275.8792963770364
# Iteration 469 return: -243.1512650706686
# Iteration 470 return: -250.47328331158604
# Iteration 471 return: -247.80619898354672
# Iteration 472 return: -230.53290438849334
# Iteration 473 return: -236.50026877640033
# Iteration 474 return: -199.75683575992795
# Iteration 475 return: -249.23072019022206
# Iteration 476 return: -211.38128373305244
# Iteration 477 return: -232.68317319881336
# Iteration 478 return: -249.53527783461604
# Iteration 479 return: -208.69260113730172
# Iteration 480 return: -289.5529427158425
# Iteration 481 return: -243.2487363190929
# Iteration 482 return: -229.22752133588025
# Iteration 483 return: -260.06776757103876
# Iteration 484 return: -224.24693060248723
# Iteration 485 return: -267.50534547206564
# Iteration 486 return: -223.04675098290147
# Iteration 487 return: -255.2821181486581
# Iteration 488 return: -267.13986072185935
# Iteration 489 return: -263.1440957140745
# Iteration 490 return: -255.95761890424896
# Iteration 491 return: -215.7565013615174
# Iteration 492 return: -268.0319160576493
# Iteration 493 return: -237.56014673173195
# Iteration 494 return: -279.75391323947724
# Iteration 495 return: -204.87471794091252
# Iteration 496 return: -228.2809137437659
# Iteration 497 return: -234.96292100676985
# Iteration 498 return: -241.7715049865524
# Iteration 499 return: -242.90014375498674
#
# ==== Training Run 1 ====
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)
# Iteration 0 return: -1244.0474938693828
# Iteration 1 return: -1232.7392441543689
# Iteration 2 return: -1170.9724020430135
# Iteration 3 return: -1129.6040848750931
# Iteration 4 return: -1106.7971483946467
# Iteration 5 return: -1112.088067504329
# Iteration 6 return: -1136.948187232303
# Iteration 7 return: -1115.5211849253562
# Iteration 8 return: -1131.1218622573504
# Iteration 9 return: -1129.9753877658793
# Iteration 10 return: -1088.364902093392
# Iteration 11 return: -1069.7486905166165
# Iteration 12 return: -1107.6513610366476
# Iteration 13 return: -1083.2013605447796
# Iteration 14 return: -1138.9409581758207
# Iteration 15 return: -1115.112617534157
# Iteration 16 return: -1120.0470811529458
# Iteration 17 return: -1122.588569667791
# Iteration 18 return: -1134.0981743606428
# Iteration 19 return: -1090.837532958053
# Iteration 20 return: -1131.569933683426
# Iteration 21 return: -1074.4421020677064
# Iteration 22 return: -1098.060653241705
# Iteration 23 return: -1097.0424260400964
# Iteration 24 return: -1109.193041986983
# Iteration 25 return: -1092.54417717427
# Iteration 26 return: -1056.5786264765013
# Iteration 27 return: -1113.7681909520613
# Iteration 28 return: -1073.7433261038652
# Iteration 29 return: -1059.9999154607967
# Iteration 30 return: -1078.9576121889877
# Iteration 31 return: -1051.5395870815155
# Iteration 32 return: -1125.139299663715
# Iteration 33 return: -1078.644988543028
# Iteration 34 return: -1105.1687020022562
# Iteration 35 return: -1080.8526499239822
# Iteration 36 return: -1106.8328029840688
# Iteration 37 return: -1076.7787286029445
# Iteration 38 return: -1059.178669995151
# Iteration 39 return: -1040.251073391779
# Iteration 40 return: -1027.1324980889121
# Iteration 41 return: -1060.664845275615
# Iteration 42 return: -1046.2772480670828
# Iteration 43 return: -1053.2186809628022
# Iteration 44 return: -1031.7499857944265
# Iteration 45 return: -1033.0465138484537
# Iteration 46 return: -1050.541343436696
# Iteration 47 return: -1031.8415767418935
# Iteration 48 return: -1033.745306184073
# Iteration 49 return: -1029.8926382717393
# Iteration 50 return: -988.8152031124803
# Iteration 51 return: -1034.1622319354985
# Iteration 52 return: -1071.7485104656282
# Iteration 53 return: -1063.1962673242472
# Iteration 54 return: -1029.9457716068966
# Iteration 55 return: -1031.7814078621454
# Iteration 56 return: -1034.3120055849097
# Iteration 57 return: -1028.3288402698017
# Iteration 58 return: -990.2209790098574
# Iteration 59 return: -969.5650702705398
# Iteration 60 return: -1006.0146571223617
# Iteration 61 return: -1005.0583070497196
# Iteration 62 return: -1000.9883941286128
# Iteration 63 return: -967.9167498180611
# Iteration 64 return: -976.0198935707743
# Iteration 65 return: -979.9742055933984
# Iteration 66 return: -1005.1400206682754
# Iteration 67 return: -1013.90822079801
# Iteration 68 return: -972.1082054378007
# Iteration 69 return: -1007.510948140376
# Iteration 70 return: -938.0274662448636
# Iteration 71 return: -976.1578457711684
# Iteration 72 return: -973.8537038773889
# Iteration 73 return: -943.6194793330269
# Iteration 74 return: -956.9596843722152
# Iteration 75 return: -950.0058486340738
# Iteration 76 return: -956.3646488808096
# Iteration 77 return: -936.0333597458208
# Iteration 78 return: -987.1721662900411
# Iteration 79 return: -965.1918732375689
# Iteration 80 return: -935.5244572657641
# Iteration 81 return: -965.7839384901679
# Iteration 82 return: -919.0978270647054
# Iteration 83 return: -944.9091277840023
# Iteration 84 return: -918.803263605147
# Iteration 85 return: -917.8879207819964
# Iteration 86 return: -936.1476094830424
# Iteration 87 return: -902.0814540818147
# Iteration 88 return: -883.531809564123
# Iteration 89 return: -918.3109661243103
# Iteration 90 return: -926.6107411064704
# Iteration 91 return: -907.3234114621984
# Iteration 92 return: -951.0689744936178
# Iteration 93 return: -918.2913377552061
# Iteration 94 return: -929.8558290601273
# Iteration 95 return: -945.480249424614
# Iteration 96 return: -940.5677476267614
# Iteration 97 return: -939.084906409209
# Iteration 98 return: -946.6640946995055
# Iteration 99 return: -903.3509226596484
# Iteration 100 return: -907.0674808038748
# Iteration 101 return: -875.9569098779301
# Iteration 102 return: -858.0789973164024
# Iteration 103 return: -886.4871151430215
# Iteration 104 return: -870.7548279368754
# Iteration 105 return: -819.1468431844617
# Iteration 106 return: -858.2452545539825
# Iteration 107 return: -856.9860312669227
# Iteration 108 return: -831.7779630334443
# Iteration 109 return: -860.2787595125163
# Iteration 110 return: -864.7349891409332
# Iteration 111 return: -868.9664079218467
# Iteration 112 return: -856.0129935340179
# Iteration 113 return: -860.3392873234975
# Iteration 114 return: -850.0758620092948
# Iteration 115 return: -851.7088824713804
# Iteration 116 return: -867.5078703559058
# Iteration 117 return: -828.3057848959385
# Iteration 118 return: -868.9517311823927
# Iteration 119 return: -858.9741952540958
# Iteration 120 return: -883.345812835133
# Iteration 121 return: -904.034087931983
# Iteration 122 return: -891.0519377569241
# Iteration 123 return: -877.9540201815124
# Iteration 124 return: -844.1810143826253
# Iteration 125 return: -772.474725758027
# Iteration 126 return: -703.2620946144708
# Iteration 127 return: -754.8119525877387
# Iteration 128 return: -674.3450325585022
# Iteration 129 return: -650.3435045931011
# Iteration 130 return: -646.3589206174281
# Iteration 131 return: -676.877278046124
# Iteration 132 return: -640.7706681916675
# Iteration 133 return: -666.3320349619266
# Iteration 134 return: -660.7815800059302
# Iteration 135 return: -668.8699777204803
# Iteration 136 return: -667.5978581818929
# Iteration 137 return: -642.8020497734908
# Iteration 138 return: -667.7629763096318
# Iteration 139 return: -595.9409715812652
# Iteration 140 return: -527.7905287915241
# Iteration 141 return: -544.1817127616672
# Iteration 142 return: -530.7901725345491
# Iteration 143 return: -490.5477182090414
# Iteration 144 return: -454.3640839467476
# Iteration 145 return: -444.0312181589981
# Iteration 146 return: -479.7840589571763
# Iteration 147 return: -393.9652109869719
# Iteration 148 return: -386.3475338899122
# Iteration 149 return: -380.50138073961784
# Iteration 150 return: -404.06150307374844
# Iteration 151 return: -374.1763966218271
# Iteration 152 return: -358.92662232283743
# Iteration 153 return: -358.29064761313253
# Iteration 154 return: -346.96746125897926
# Iteration 155 return: -366.8197813779624
# Iteration 156 return: -336.59282631014037
# Iteration 157 return: -393.31434524835106
# Iteration 158 return: -389.2237878406662
# Iteration 159 return: -374.51206434567297
# Iteration 160 return: -434.62102723360346
# Iteration 161 return: -420.6043892316183
# Iteration 162 return: -378.65249301784394
# Iteration 163 return: -424.2797607385529
# Iteration 164 return: -424.52369628660495
# Iteration 165 return: -340.9258610775773
# Iteration 166 return: -314.6670913109802
# Iteration 167 return: -335.496806974764
# Iteration 168 return: -336.2888233305179
# Iteration 169 return: -358.8697773263695
# Iteration 170 return: -351.88911714553535
# Iteration 171 return: -362.5495375810648
# Iteration 172 return: -346.7671847807917
# Iteration 173 return: -288.2042253364286
# Iteration 174 return: -369.86285087460595
# Iteration 175 return: -364.46788192059904
# Iteration 176 return: -346.13230287810376
# Iteration 177 return: -368.46181485533384
# Iteration 178 return: -319.46030874274305
# Iteration 179 return: -281.61237018769066
# Iteration 180 return: -363.8648583528049
# Iteration 181 return: -376.12146264273593
# Iteration 182 return: -363.0937477517578
# Iteration 183 return: -296.30097097885147
# Iteration 184 return: -274.1583566828104
# Iteration 185 return: -354.5039124541504
# Iteration 186 return: -317.54121846435123
# Iteration 187 return: -285.85768719683364
# Iteration 188 return: -346.65993008069216
# Iteration 189 return: -296.6346679696369
# Iteration 190 return: -284.1365897656319
# Iteration 191 return: -354.5777240416423
# Iteration 192 return: -319.1793871324106
# Iteration 193 return: -304.9638162052671
# Iteration 194 return: -314.43834428924293
# Iteration 195 return: -364.1131935321063
# Iteration 196 return: -255.17775924723043
# Iteration 197 return: -280.7015067455236
# Iteration 198 return: -311.94249908801305
# Iteration 199 return: -303.2579979106047
# Iteration 200 return: -305.63672732363
# Iteration 201 return: -312.5879703162703
# Iteration 202 return: -289.87757480284785
# Iteration 203 return: -299.86440310048107
# Iteration 204 return: -332.20268463696976
# Iteration 205 return: -264.6090838197153
# Iteration 206 return: -290.4139888393505
# Iteration 207 return: -272.8029195764225
# Iteration 208 return: -298.304865545863
# Iteration 209 return: -236.2088959383978
# Iteration 210 return: -259.5476512207032
# Iteration 211 return: -311.8346608218488
# Iteration 212 return: -289.2830657684007
# Iteration 213 return: -283.23699624345414
# Iteration 214 return: -259.7017053757051
# Iteration 215 return: -274.9352534243804
# Iteration 216 return: -282.596723483361
# Iteration 217 return: -261.2874114957655
# Iteration 218 return: -261.88411763590466
# Iteration 219 return: -291.85750681293774
# Iteration 220 return: -273.32274241418986
# Iteration 221 return: -303.4334277819033
# Iteration 222 return: -299.3677309834062
# Iteration 223 return: -261.45584379529174
# Iteration 224 return: -292.2682381674316
# Iteration 225 return: -303.340848870285
# Iteration 226 return: -236.5754219966762
# Iteration 227 return: -277.5298418374146
# Iteration 228 return: -297.7444836502006
# Iteration 229 return: -254.22908494340174
# Iteration 230 return: -277.0731413530529
# Iteration 231 return: -316.2467612252738
# Iteration 232 return: -239.31684126137262
# Iteration 233 return: -276.8606354277456
# Iteration 234 return: -289.7814997202875
# Iteration 235 return: -250.44361221836672
# Iteration 236 return: -257.1402643944161
# Iteration 237 return: -281.1187045687932
# Iteration 238 return: -259.9225167186408
# Iteration 239 return: -285.4764293909679
# Iteration 240 return: -280.16712163779863
# Iteration 241 return: -265.6640010509339
# Iteration 242 return: -258.03791899466773
# Iteration 243 return: -297.65160433010004
# Iteration 244 return: -287.05409423138605
# Iteration 245 return: -313.3266702718871
# Iteration 246 return: -287.19984737188764
# Iteration 247 return: -289.98067169577917
# Iteration 248 return: -283.3407612490996
# Iteration 249 return: -289.5120148853106
# Iteration 250 return: -267.04621383586317
# Iteration 251 return: -257.7562381657912
# Iteration 252 return: -252.4511055539366
# Iteration 253 return: -279.1710945952871
# Iteration 254 return: -320.54019694883385
# Iteration 255 return: -266.995527747642
# Iteration 256 return: -272.3470860083044
# Iteration 257 return: -254.39474174222505
# Iteration 258 return: -266.7106141669899
# Iteration 259 return: -315.7791107184728
# Iteration 260 return: -300.65918994509286
# Iteration 261 return: -263.62780236790815
# Iteration 262 return: -251.3220009140585
# Iteration 263 return: -289.1755338344809
# Iteration 264 return: -293.6937528856839
# Iteration 265 return: -305.70478898614607
# Iteration 266 return: -260.59315403753357
# Iteration 267 return: -289.6730253430413
# Iteration 268 return: -274.02707959595455
# Iteration 269 return: -294.7796893867925
# Iteration 270 return: -277.297835349925
# Iteration 271 return: -304.50758664655814
# Iteration 272 return: -301.4155789661557
# Iteration 273 return: -300.1918816717837
# Iteration 274 return: -274.04914940084103
# Iteration 275 return: -242.74920960362934
# Iteration 276 return: -240.84991691701987
# Iteration 277 return: -288.0480453745538
# Iteration 278 return: -251.99970251188677
# Iteration 279 return: -302.42151968844956
# Iteration 280 return: -306.5496438082754
# Iteration 281 return: -296.11407658124557
# Iteration 282 return: -242.53023228515192
# Iteration 283 return: -274.8549019843312
# Iteration 284 return: -302.78198336766354
# Iteration 285 return: -313.3911668968244
# Iteration 286 return: -340.0280083681845
# Iteration 287 return: -255.1321427216923
# Iteration 288 return: -283.6800597615761
# Iteration 289 return: -237.50572272561965
# Iteration 290 return: -262.0999537592852
# Iteration 291 return: -287.82869044545674
# Iteration 292 return: -298.0442570216707
# Iteration 293 return: -284.5669142315525
# Iteration 294 return: -280.32129973995507
# Iteration 295 return: -262.46365795462555
# Iteration 296 return: -230.7066728429437
# Iteration 297 return: -298.614469889082
# Iteration 298 return: -282.8246332864414
# Iteration 299 return: -303.8494494422094
# Iteration 300 return: -304.1530253361537
# Iteration 301 return: -280.1542917419229
# Iteration 302 return: -278.3013150681716
# Iteration 303 return: -275.72339406717686
# Iteration 304 return: -251.40728198010873
# Iteration 305 return: -246.3204330966089
# Iteration 306 return: -257.00530303304686
# Iteration 307 return: -263.32821902019697
# Iteration 308 return: -235.57496797011908
# Iteration 309 return: -276.060079066887
# Iteration 310 return: -281.0095762258229
# Iteration 311 return: -306.8708093773806
# Iteration 312 return: -228.55721155488848
# Iteration 313 return: -251.43376323344364
# Iteration 314 return: -266.87121767808935
# Iteration 315 return: -301.58152083314525
# Iteration 316 return: -262.5617969447132
# Iteration 317 return: -242.19241692244006
# Iteration 318 return: -262.9785316510142
# Iteration 319 return: -295.1144602643611
# Iteration 320 return: -255.32555812896064
# Iteration 321 return: -231.2387680748309
# Iteration 322 return: -272.45058774927276
# Iteration 323 return: -308.96107530479054
# Iteration 324 return: -252.42360491444444
# Iteration 325 return: -324.466795313216
# Iteration 326 return: -271.2078756967324
# Iteration 327 return: -252.19635675877575
# Iteration 328 return: -277.09205936505754
# Iteration 329 return: -292.97283436788365
# Iteration 330 return: -257.4867998406573
# Iteration 331 return: -256.34857422102243
# Iteration 332 return: -265.71142653061224
# Iteration 333 return: -253.84435489603217
# Iteration 334 return: -266.52225821091616
# Iteration 335 return: -260.3168651796128
# Iteration 336 return: -263.425362464366
# Iteration 337 return: -292.32386519196734
# Iteration 338 return: -262.95229089227837
# Iteration 339 return: -281.9397366454917
# Iteration 340 return: -276.07054944763195
# Iteration 341 return: -272.23368425078434
# Iteration 342 return: -262.77989416634915
# Iteration 343 return: -242.62568863643887
# Iteration 344 return: -282.3672372998307
# Iteration 345 return: -250.8432790053518
# Iteration 346 return: -293.30266678957395
# Iteration 347 return: -242.34052260902675
# Iteration 348 return: -265.47842662030865
# Iteration 349 return: -237.19592327119423
# Iteration 350 return: -274.21854430334315
# Iteration 351 return: -270.38442886687676
# Iteration 352 return: -257.63243956324806
# Iteration 353 return: -252.83399841943066
# Iteration 354 return: -239.8318851791004
# Iteration 355 return: -279.0162362093159
# Iteration 356 return: -254.39363635459716
# Iteration 357 return: -280.03349139040915
# Iteration 358 return: -240.85301437367306
# Iteration 359 return: -265.61341622992205
# Iteration 360 return: -261.1663632410751
# Iteration 361 return: -278.57130901680546
# Iteration 362 return: -249.73718021845715
# Iteration 363 return: -268.00354338658116
# Iteration 364 return: -264.0767099098238
# Iteration 365 return: -242.98924528430862
# Iteration 366 return: -284.65366321437097
# Iteration 367 return: -256.90312448672114
# Iteration 368 return: -258.28378079593637
# Iteration 369 return: -263.25408044466326
# Iteration 370 return: -261.4938976764975
# Iteration 371 return: -256.6510925752298
# Iteration 372 return: -245.5610897230831
# Iteration 373 return: -248.1798150169311
# Iteration 374 return: -301.4771662451296
# Iteration 375 return: -273.2777094090731
# Iteration 376 return: -246.61583387283375
# Iteration 377 return: -274.7062251575386
# Iteration 378 return: -250.67183446113083
# Iteration 379 return: -251.29657795695724
# Iteration 380 return: -264.48883531376316
# Iteration 381 return: -268.2410943930634
# Iteration 382 return: -298.29022102538147
# Iteration 383 return: -274.59980337247146
# Iteration 384 return: -284.60132958755133
# Iteration 385 return: -240.9310560571839
# Iteration 386 return: -293.02097801012917
# Iteration 387 return: -271.44049554174984
# Iteration 388 return: -274.1752799575021
# Iteration 389 return: -242.60612652521823
# Iteration 390 return: -271.5189698453292
# Iteration 391 return: -287.1337364631477
# Iteration 392 return: -274.69808097526646
# Iteration 393 return: -280.27174700314356
# Iteration 394 return: -300.82818966351
# Iteration 395 return: -234.6656255186587
# Iteration 396 return: -247.4472366100005
# Iteration 397 return: -254.58868710552392
# Iteration 398 return: -257.61017676748685
# Iteration 399 return: -300.02227183667736
# Iteration 400 return: -260.3561372437421
# Iteration 401 return: -244.44456416463092
# Iteration 402 return: -269.3996759005323
# Iteration 403 return: -291.20171802206846
# Iteration 404 return: -281.65625165977775
# Iteration 405 return: -302.49714364262474
# Iteration 406 return: -250.35932477823678
# Iteration 407 return: -243.31201349342973
# Iteration 408 return: -253.63593578397922
# Iteration 409 return: -272.2210694757243
# Iteration 410 return: -264.31665893969233
# Iteration 411 return: -294.22362901193856
# Iteration 412 return: -297.3663236192935
# Iteration 413 return: -236.47319078851064
# Iteration 414 return: -265.09663555594295
# Iteration 415 return: -294.799770921947
# Iteration 416 return: -285.04324560551737
# Iteration 417 return: -257.5742128077753
# Iteration 418 return: -279.1476170674007
# Iteration 419 return: -329.7235438509165
# Iteration 420 return: -267.8921764934694
# Iteration 421 return: -265.2597857100171
# Iteration 422 return: -252.04562789568067
# Iteration 423 return: -299.3409923178203
# Iteration 424 return: -272.28832521964245
# Iteration 425 return: -270.84653104647765
# Iteration 426 return: -252.72726720746675
# Iteration 427 return: -243.91323616277765
# Iteration 428 return: -262.4756330345781
# Iteration 429 return: -278.23315110337757
# Iteration 430 return: -229.97844718642253
# Iteration 431 return: -276.17879732799815
# Iteration 432 return: -300.0827499592069
# Iteration 433 return: -231.53824602391032
# Iteration 434 return: -273.7359182759062
# Iteration 435 return: -315.7592765696645
# Iteration 436 return: -291.4199237826339
# Iteration 437 return: -250.65620161619358
# Iteration 438 return: -284.98682451945933
# Iteration 439 return: -284.35033441264136
# Iteration 440 return: -286.15204882463587
# Iteration 441 return: -272.5342818086678
# Iteration 442 return: -272.5588167872683
# Iteration 443 return: -271.17871569410556
# Iteration 444 return: -271.9134701820374
# Iteration 445 return: -268.5852540940391
# Iteration 446 return: -301.87179339030854
# Iteration 447 return: -314.5447236471229
# Iteration 448 return: -305.59605279245557
# Iteration 449 return: -243.99087981250713
# Iteration 450 return: -289.510402922786
# Iteration 451 return: -248.5837977229538
# Iteration 452 return: -265.75776697027266
# Iteration 453 return: -276.7834844018036
# Iteration 454 return: -265.5269345031488
# Iteration 455 return: -247.02969101760507
# Iteration 456 return: -291.44197979700914
# Iteration 457 return: -287.76153596855573
# Iteration 458 return: -257.042636003559
# Iteration 459 return: -281.47054755537357
# Iteration 460 return: -282.6334051768103
# Iteration 461 return: -278.6922549998862
# Iteration 462 return: -260.3071971159152
# Iteration 463 return: -271.1511103141165
# Iteration 464 return: -262.1512995056768
# Iteration 465 return: -275.85206802082485
# Iteration 466 return: -303.2632335840362
# Iteration 467 return: -274.65335171077345
# Iteration 468 return: -283.6582291109453
# Iteration 469 return: -279.75164286104103
# Iteration 470 return: -268.20140882717226
# Iteration 471 return: -238.9682536970823
# Iteration 472 return: -272.0604104407745
# Iteration 473 return: -249.4792096628347
# Iteration 474 return: -240.71267184113367
# Iteration 475 return: -269.35944263932055
# Iteration 476 return: -273.73451706608233
# Iteration 477 return: -277.55341140535467
# Iteration 478 return: -266.7431708193525
# Iteration 479 return: -225.83734315497657
# Iteration 480 return: -253.4276683313774
# Iteration 481 return: -263.15639910856504
# Iteration 482 return: -250.64702590093918
# Iteration 483 return: -269.14138968597297
# Iteration 484 return: -245.0570730084505
# Iteration 485 return: -270.03540718887524
# Iteration 486 return: -273.1749600697916
# Iteration 487 return: -304.6308621503695
# Iteration 488 return: -222.51935575872128
# Iteration 489 return: -263.6050608049137
# Iteration 490 return: -274.68150215642845
# Iteration 491 return: -246.84874408197715
# Iteration 492 return: -268.39888525712377
# Iteration 493 return: -237.79213418956624
# Iteration 494 return: -241.7054522226372
# Iteration 495 return: -244.20608750192525
# Iteration 496 return: -279.9909233624735
# Iteration 497 return: -253.25230606751114
# Iteration 498 return: -292.6730740736532
# Iteration 499 return: -275.66855510435556
#
# ==== Training Run 2 ====
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)
# Iteration 0 return: -1274.3590277770318
# Iteration 1 return: -1188.5418677262353
# Iteration 2 return: -1131.4054540803097
# Iteration 3 return: -1137.571554912425
# Iteration 4 return: -1127.1835894682476
# Iteration 5 return: -1137.4956797709938
# Iteration 6 return: -1112.5192482352227
# Iteration 7 return: -1149.8502218728079
# Iteration 8 return: -1102.0828211675118
# Iteration 9 return: -1145.8950352594054
# Iteration 10 return: -1148.9449688789498
# Iteration 11 return: -1122.4759462876557
# Iteration 12 return: -1101.4966969034697
# Iteration 13 return: -1096.6766404909338
# Iteration 14 return: -1123.0710031230003
# Iteration 15 return: -1119.0364060172749
# Iteration 16 return: -1116.412659237689
# Iteration 17 return: -1095.7008402736112
# Iteration 18 return: -1152.6632379499079
# Iteration 19 return: -1155.2233503627265
# Iteration 20 return: -1119.1559114195718
# Iteration 21 return: -1152.6647768903322
# Iteration 22 return: -1100.4997825993582
# Iteration 23 return: -1161.873250973881
# Iteration 24 return: -1133.4338375233485
# Iteration 25 return: -1150.020747308426
# Iteration 26 return: -1164.2180086926883
# Iteration 27 return: -1155.4369240733608
# Iteration 28 return: -1157.163090323371
# Iteration 29 return: -1141.6177062825727
# Iteration 30 return: -1150.676235199701
# Iteration 31 return: -1161.0067677576099
# Iteration 32 return: -1163.817169250492
# Iteration 33 return: -1167.8819512468515
# Iteration 34 return: -1150.5808042556916
# Iteration 35 return: -1158.0542451567142
# Iteration 36 return: -1111.8235926557861
# Iteration 37 return: -1157.5466575172288
# Iteration 38 return: -1131.6666318525497
# Iteration 39 return: -1083.1482845818996
# Iteration 40 return: -1112.4591676111054
# Iteration 41 return: -1112.6342390959524
# Iteration 42 return: -1118.0281471564963
# Iteration 43 return: -1112.0692898515192
# Iteration 44 return: -1127.9471359532156
# Iteration 45 return: -1084.6316443200285
# Iteration 46 return: -1073.4612481019833
# Iteration 47 return: -1065.5251905866526
# Iteration 48 return: -1034.8082404513223
# Iteration 49 return: -1080.478702416687
# Iteration 50 return: -1061.824885831736
# Iteration 51 return: -1052.1717285983
# Iteration 52 return: -1059.925325523101
# Iteration 53 return: -1068.4127881459178
# Iteration 54 return: -1045.3799621582466
# Iteration 55 return: -1018.3496330584647
# Iteration 56 return: -1061.698540505298
# Iteration 57 return: -1033.0395127253173
# Iteration 58 return: -1035.2242222953964
# Iteration 59 return: -1038.109184927739
# Iteration 60 return: -1060.6504312311245
# Iteration 61 return: -1062.0413027748807
# Iteration 62 return: -1013.5418376823453
# Iteration 63 return: -1044.314807239027
# Iteration 64 return: -1031.1852667688393
# Iteration 65 return: -1062.9342900479212
# Iteration 66 return: -1061.459982910998
# Iteration 67 return: -1050.1878234139892
# Iteration 68 return: -1057.2801749887815
# Iteration 69 return: -1038.3904917961127
# Iteration 70 return: -1032.759437428511
# Iteration 71 return: -1081.8343909703692
# Iteration 72 return: -1031.6113365396702
# Iteration 73 return: -1076.8444275998263
# Iteration 74 return: -1077.31756479407
# Iteration 75 return: -1040.2595289556
# Iteration 76 return: -1027.0296196469478
# Iteration 77 return: -993.2216162282151
# Iteration 78 return: -1000.0295974809972
# Iteration 79 return: -983.1416041435095
# Iteration 80 return: -981.1965559922144
# Iteration 81 return: -1022.0427507641213
# Iteration 82 return: -969.4879077901256
# Iteration 83 return: -986.5464582532567
# Iteration 84 return: -974.4983451758977
# Iteration 85 return: -1020.2919767531761
# Iteration 86 return: -990.2833847008055
# Iteration 87 return: -1009.2827740054702
# Iteration 88 return: -1046.8965193264094
# Iteration 89 return: -1070.6032289891007
# Iteration 90 return: -1063.6490420702287
# Iteration 91 return: -1075.4612721473661
# Iteration 92 return: -1043.9196689222101
# Iteration 93 return: -1059.893388943492
# Iteration 94 return: -1032.8461727239874
# Iteration 95 return: -1064.5155987273777
# Iteration 96 return: -1006.4964487889968
# Iteration 97 return: -1005.8944096958991
# Iteration 98 return: -992.0656413651692
# Iteration 99 return: -985.7014263497293
# Iteration 100 return: -919.2799093000249
# Iteration 101 return: -959.2775061092697
# Iteration 102 return: -960.236823393164
# Iteration 103 return: -935.657204495954
# Iteration 104 return: -942.8367757746647
# Iteration 105 return: -957.237792639127
# Iteration 106 return: -940.5875467569268
# Iteration 107 return: -929.0543325627165
# Iteration 108 return: -877.358886240649
# Iteration 109 return: -900.9250088287874
# Iteration 110 return: -889.7912728207341
# Iteration 111 return: -910.4523938035328
# Iteration 112 return: -897.374242745048
# Iteration 113 return: -918.6111018946735
# Iteration 114 return: -984.6111216158513
# Iteration 115 return: -1028.7456424047239
# Iteration 116 return: -978.4889735245565
# Iteration 117 return: -1025.1027249774904
# Iteration 118 return: -992.8071813527968
# Iteration 119 return: -983.7660855333942
# Iteration 120 return: -983.8556843757877
# Iteration 121 return: -939.1820741807576
# Iteration 122 return: -895.1622247918424
# Iteration 123 return: -890.3442949036687
# Iteration 124 return: -883.6315814736846
# Iteration 125 return: -887.4311119449325
# Iteration 126 return: -854.7476175758444
# Iteration 127 return: -871.9457892474536
# Iteration 128 return: -847.3636256314988
# Iteration 129 return: -851.7986336315618
# Iteration 130 return: -879.4888422814951
# Iteration 131 return: -810.3094277243868
# Iteration 132 return: -803.7025536870387
# Iteration 133 return: -748.9764987343007
# Iteration 134 return: -710.2813051428856
# Iteration 135 return: -641.3123306997279
# Iteration 136 return: -616.0786304496754
# Iteration 137 return: -608.5627059554926
# Iteration 138 return: -582.9023163374844
# Iteration 139 return: -594.9886239786962
# Iteration 140 return: -609.291894255375
# Iteration 141 return: -555.5807457758898
# Iteration 142 return: -542.1397617872917
# Iteration 143 return: -447.18575315135985
# Iteration 144 return: -488.43224535750284
# Iteration 145 return: -479.5292545823841
# Iteration 146 return: -535.0997277081144
# Iteration 147 return: -470.7098941570376
# Iteration 148 return: -462.68671939130456
# Iteration 149 return: -451.481515211389
# Iteration 150 return: -445.48050501593895
# Iteration 151 return: -530.7599371830374
# Iteration 152 return: -414.2600121419361
# Iteration 153 return: -449.9390679158188
# Iteration 154 return: -421.4839139569252
# Iteration 155 return: -385.93771034245833
# Iteration 156 return: -368.0523963606246
# Iteration 157 return: -403.8807900613549
# Iteration 158 return: -382.56520490089594
# Iteration 159 return: -343.3371073332897
# Iteration 160 return: -366.32296156702347
# Iteration 161 return: -296.51506003472286
# Iteration 162 return: -340.3169724647607
# Iteration 163 return: -313.5617023980625
# Iteration 164 return: -368.2075760697237
# Iteration 165 return: -333.8423280726725
# Iteration 166 return: -264.9166736234507
# Iteration 167 return: -309.3241075144453
# Iteration 168 return: -343.497546252578
# Iteration 169 return: -358.4622770366046
# Iteration 170 return: -322.76439060666286
# Iteration 171 return: -378.02119941353044
# Iteration 172 return: -319.12201454162897
# Iteration 173 return: -328.4367638479553
# Iteration 174 return: -349.3609561674819
# Iteration 175 return: -383.82094837586243
# Iteration 176 return: -347.9285172660172
# Iteration 177 return: -401.07834325324006
# Iteration 178 return: -304.0497041002251
# Iteration 179 return: -357.50298416389006
# Iteration 180 return: -342.6925962935912
# Iteration 181 return: -354.46573114199913
# Iteration 182 return: -339.0921340589111
# Iteration 183 return: -285.84474776701927
# Iteration 184 return: -376.6342661995817
# Iteration 185 return: -305.9550950675845
# Iteration 186 return: -273.41167087380165
# Iteration 187 return: -338.58994877791736
# Iteration 188 return: -302.77962158484405
# Iteration 189 return: -316.2583432022383
# Iteration 190 return: -376.36944756922503
# Iteration 191 return: -357.5915100738706
# Iteration 192 return: -353.44118076446824
# Iteration 193 return: -354.4464756206723
# Iteration 194 return: -337.7862037994397
# Iteration 195 return: -302.84054365685
# Iteration 196 return: -349.6048972720151
# Iteration 197 return: -330.8000067398142
# Iteration 198 return: -328.7165191510161
# Iteration 199 return: -339.59759411837933
# Iteration 200 return: -351.655838949053
# Iteration 201 return: -338.17421447118073
# Iteration 202 return: -323.4051144805143
# Iteration 203 return: -347.3012011013445
# Iteration 204 return: -357.77782245138394
# Iteration 205 return: -360.0725588452138
# Iteration 206 return: -355.0184906006123
# Iteration 207 return: -328.5313993380693
# Iteration 208 return: -344.1666099888569
# Iteration 209 return: -397.0205229896119
# Iteration 210 return: -298.87234998567
# Iteration 211 return: -358.3363738301891
# Iteration 212 return: -329.4747594584504
# Iteration 213 return: -345.34122583819686
# Iteration 214 return: -299.5568348923174
# Iteration 215 return: -359.6711305606491
# Iteration 216 return: -294.2075651193952
# Iteration 217 return: -301.8047468248065
# Iteration 218 return: -329.17176176686667
# Iteration 219 return: -372.4423902339164
# Iteration 220 return: -343.5599925595066
# Iteration 221 return: -303.540511387029
# Iteration 222 return: -326.1558034601878
# Iteration 223 return: -344.0446490703734
# Iteration 224 return: -289.13882498714406
# Iteration 225 return: -288.4830439198496
# Iteration 226 return: -330.06211441128613
# Iteration 227 return: -257.06633414289894
# Iteration 228 return: -333.7101541430016
# Iteration 229 return: -297.882174387337
# Iteration 230 return: -288.0121073522613
# Iteration 231 return: -257.063813499828
# Iteration 232 return: -351.83256362207914
# Iteration 233 return: -342.28264771131455
# Iteration 234 return: -302.89935556333523
# Iteration 235 return: -342.4975509456462
# Iteration 236 return: -304.4849793235885
# Iteration 237 return: -325.2220035634325
# Iteration 238 return: -281.1048524160371
# Iteration 239 return: -331.1227062585349
# Iteration 240 return: -269.1102841631716
# Iteration 241 return: -310.7329884707387
# Iteration 242 return: -352.0487436757343
# Iteration 243 return: -287.9849860247961
# Iteration 244 return: -261.4721308044643
# Iteration 245 return: -301.0311260852207
# Iteration 246 return: -330.5398191049041
# Iteration 247 return: -314.59154130675097
# Iteration 248 return: -294.6175374453577
# Iteration 249 return: -312.05102903806716
# Iteration 250 return: -260.61810238095
# Iteration 251 return: -301.3687476255601
# Iteration 252 return: -277.7588324643594
# Iteration 253 return: -321.6660251632881
# Iteration 254 return: -298.8221134721869
# Iteration 255 return: -323.04146564561506
# Iteration 256 return: -290.34836443770325
# Iteration 257 return: -329.38677176801684
# Iteration 258 return: -327.85695542838454
# Iteration 259 return: -318.28430818224246
# Iteration 260 return: -300.87733909249175
# Iteration 261 return: -280.8152715539257
# Iteration 262 return: -291.4132996212671
# Iteration 263 return: -329.73562282532043
# Iteration 264 return: -356.90512198133666
# Iteration 265 return: -321.18377049108256
# Iteration 266 return: -291.3297336644697
# Iteration 267 return: -335.99963316210506
# Iteration 268 return: -296.40395442588556
# Iteration 269 return: -302.76737509374374
# Iteration 270 return: -313.8145469622159
# Iteration 271 return: -309.9413473524991
# Iteration 272 return: -262.8885800477312
# Iteration 273 return: -324.39796165145606
# Iteration 274 return: -271.3893318327552
# Iteration 275 return: -323.7280569207806
# Iteration 276 return: -265.26947828180136
# Iteration 277 return: -274.83126137785695
# Iteration 278 return: -271.40678517456945
# Iteration 279 return: -283.2545802806686
# Iteration 280 return: -304.90383429002185
# Iteration 281 return: -309.8770853985904
# Iteration 282 return: -263.98582158142113
# Iteration 283 return: -311.36268896367187
# Iteration 284 return: -272.15675397209435
# Iteration 285 return: -244.92242391448988
# Iteration 286 return: -273.4850268145681
# Iteration 287 return: -288.2547300886754
# Iteration 288 return: -286.55608010290064
# Iteration 289 return: -273.6105018931155
# Iteration 290 return: -256.95503591574965
# Iteration 291 return: -272.0530109386399
# Iteration 292 return: -294.41141146947183
# Iteration 293 return: -276.18925492382607
# Iteration 294 return: -313.5147220951111
# Iteration 295 return: -279.4568593766003
# Iteration 296 return: -322.22289998229365
# Iteration 297 return: -299.7210154704765
# Iteration 298 return: -268.5490919179887
# Iteration 299 return: -285.74892405463004
# Iteration 300 return: -280.5115782795598
# Iteration 301 return: -282.71075829021765
# Iteration 302 return: -245.2140191249785
# Iteration 303 return: -270.66903778726567
# Iteration 304 return: -311.3200772541297
# Iteration 305 return: -292.1553256311905
# Iteration 306 return: -286.71328388213306
# Iteration 307 return: -309.04316194351406
# Iteration 308 return: -259.61104187930385
# Iteration 309 return: -330.4962414741185
# Iteration 310 return: -259.0074514855613
# Iteration 311 return: -242.4968503650167
# Iteration 312 return: -282.0707644932914
# Iteration 313 return: -333.602556052273
# Iteration 314 return: -282.18089511021407
# Iteration 315 return: -306.11233032509983
# Iteration 316 return: -282.5715191580644
# Iteration 317 return: -283.5204187556098
# Iteration 318 return: -276.0888626511369
# Iteration 319 return: -271.24897833716125
# Iteration 320 return: -253.06340915455735
# Iteration 321 return: -244.22833207304484
# Iteration 322 return: -304.08284086225916
# Iteration 323 return: -264.5520261902168
# Iteration 324 return: -312.2965880756903
# Iteration 325 return: -285.78524291764586
# Iteration 326 return: -274.1551448037334
# Iteration 327 return: -271.8151356802353
# Iteration 328 return: -294.45430094623475
# Iteration 329 return: -259.81733856992827
# Iteration 330 return: -299.62170712140096
# Iteration 331 return: -248.67501013380135
# Iteration 332 return: -238.8378204455319
# Iteration 333 return: -249.02854896183314
# Iteration 334 return: -306.8473061171133
# Iteration 335 return: -273.8310109769887
# Iteration 336 return: -240.02102377611047
# Iteration 337 return: -310.0328697939311
# Iteration 338 return: -305.28517332568543
# Iteration 339 return: -326.82100175226697
# Iteration 340 return: -281.14897190263986
# Iteration 341 return: -243.93025393915417
# Iteration 342 return: -318.00593897589937
# Iteration 343 return: -297.5422907631219
# Iteration 344 return: -293.4542751848886
# Iteration 345 return: -272.4697155912147
# Iteration 346 return: -347.2393375980994
# Iteration 347 return: -294.1918164787906
# Iteration 348 return: -295.3438507702114
# Iteration 349 return: -260.12898091904356
# Iteration 350 return: -321.4897045585802
# Iteration 351 return: -362.61986360345446
# Iteration 352 return: -300.18855217961476
# Iteration 353 return: -286.2422332489575
# Iteration 354 return: -274.9781344169317
# Iteration 355 return: -324.37514608700025
# Iteration 356 return: -308.095867105698
# Iteration 357 return: -287.4304417983341
# Iteration 358 return: -323.09575128435955
# Iteration 359 return: -298.4039169272962
# Iteration 360 return: -291.23010970053184
# Iteration 361 return: -281.14239191276596
# Iteration 362 return: -272.78189291358586
# Iteration 363 return: -278.72766387973167
# Iteration 364 return: -297.07936276800217
# Iteration 365 return: -299.8385609463178
# Iteration 366 return: -281.4353647347809
# Iteration 367 return: -235.57531823576565
# Iteration 368 return: -294.6579481666705
# Iteration 369 return: -324.035224313774
# Iteration 370 return: -276.02622339128806
# Iteration 371 return: -308.86407604883846
# Iteration 372 return: -327.2882606375284
# Iteration 373 return: -324.13650515769115
# Iteration 374 return: -288.71573533293804
# Iteration 375 return: -288.7866788059703
# Iteration 376 return: -311.5013308443368
# Iteration 377 return: -265.32360731455293
# Iteration 378 return: -285.907940299
# Iteration 379 return: -356.45223361027007
# Iteration 380 return: -280.03631799536805
# Iteration 381 return: -252.7740562141462
# Iteration 382 return: -356.5247697685141
# Iteration 383 return: -324.67370273694684
# Iteration 384 return: -310.4717157856111
# Iteration 385 return: -273.4713813340494
# Iteration 386 return: -274.8909631622346
# Iteration 387 return: -276.2006648661362
# Iteration 388 return: -306.5523675194568
# Iteration 389 return: -301.6242920028886
# Iteration 390 return: -333.0472658973226
# Iteration 391 return: -287.8747859050856
# Iteration 392 return: -282.87041900880104
# Iteration 393 return: -314.5297342011669
# Iteration 394 return: -268.8764319270058
# Iteration 395 return: -290.1393900005791
# Iteration 396 return: -315.0908428194649
# Iteration 397 return: -310.9445797660177
# Iteration 398 return: -312.315615819848
# Iteration 399 return: -255.01842027289103
# Iteration 400 return: -285.64108165307385
# Iteration 401 return: -278.85504695106005
# Iteration 402 return: -327.05017762068996
# Iteration 403 return: -304.2368318597305
# Iteration 404 return: -288.197640431609
# Iteration 405 return: -284.2017571876844
# Iteration 406 return: -294.5006916636587
# Iteration 407 return: -286.9242740652128
# Iteration 408 return: -298.8199115710081
# Iteration 409 return: -325.49788089194493
# Iteration 410 return: -290.65421500723846
# Iteration 411 return: -289.15813703876796
# Iteration 412 return: -315.0814143312667
# Iteration 413 return: -236.44194872275853
# Iteration 414 return: -265.5596049498776
# Iteration 415 return: -271.04564357595706
# Iteration 416 return: -297.3142444374717
# Iteration 417 return: -247.05859286395463
# Iteration 418 return: -244.040082674052
# Iteration 419 return: -325.8355021036396
# Iteration 420 return: -293.3274813053097
# Iteration 421 return: -290.26280589060065
# Iteration 422 return: -276.24131716191465
# Iteration 423 return: -273.7142856595597
# Iteration 424 return: -284.4230181252669
# Iteration 425 return: -293.3997356334043
# Iteration 426 return: -279.801267578161
# Iteration 427 return: -330.96972483530243
# Iteration 428 return: -276.69380743832386
# Iteration 429 return: -266.9663366575183
# Iteration 430 return: -335.2858094525387
# Iteration 431 return: -282.7914782496597
# Iteration 432 return: -282.9309120099631
# Iteration 433 return: -291.0409250776071
# Iteration 434 return: -314.1285423350701
# Iteration 435 return: -297.0490198881358
# Iteration 436 return: -254.67610342673734
# Iteration 437 return: -321.5834817589684
# Iteration 438 return: -278.38981496575394
# Iteration 439 return: -266.4959472945702
# Iteration 440 return: -311.9463575963212
# Iteration 441 return: -256.1960418432427
# Iteration 442 return: -316.9031792691915
# Iteration 443 return: -276.18791601129124
# Iteration 444 return: -256.2203119389131
# Iteration 445 return: -332.2067759419288
# Iteration 446 return: -290.8702038897417
# Iteration 447 return: -255.87470480511067
# Iteration 448 return: -293.81086736403336
# Iteration 449 return: -298.1653634099192
# Iteration 450 return: -269.894162967323
# Iteration 451 return: -261.98681808089697
# Iteration 452 return: -262.731949523876
# Iteration 453 return: -239.93994629757876
# Iteration 454 return: -275.892455746879
# Iteration 455 return: -298.64634457199924
# Iteration 456 return: -326.70864180878834
# Iteration 457 return: -286.0941557067971
# Iteration 458 return: -295.64453802948333
# Iteration 459 return: -338.99181228240906
# Iteration 460 return: -306.54533434461143
# Iteration 461 return: -257.4980905143899
# Iteration 462 return: -248.5929405217401
# Iteration 463 return: -246.84566557562536
# Iteration 464 return: -319.40871562001354
# Iteration 465 return: -254.72850312615958
# Iteration 466 return: -286.4211583325028
# Iteration 467 return: -292.960794246984
# Iteration 468 return: -298.92482781802653
# Iteration 469 return: -262.7509175490129
# Iteration 470 return: -265.70239148369126
# Iteration 471 return: -307.60541471710025
# Iteration 472 return: -295.09672154709176
# Iteration 473 return: -301.9723147651918
# Iteration 474 return: -255.16939786161063
# Iteration 475 return: -276.353038352649
# Iteration 476 return: -301.2482510204599
# Iteration 477 return: -287.1772883229697
# Iteration 478 return: -269.82581982294244
# Iteration 479 return: -314.2329065672374
# Iteration 480 return: -302.46333146800237
# Iteration 481 return: -255.7984837102546
# Iteration 482 return: -299.2733430578237
# Iteration 483 return: -284.5405327779619
# Iteration 484 return: -301.5797376015049
# Iteration 485 return: -286.2842226973919
# Iteration 486 return: -279.135287671869
# Iteration 487 return: -298.22460340894895
# Iteration 488 return: -255.68650766029538
# Iteration 489 return: -258.23273245698203
# Iteration 490 return: -265.19968039947673
# Iteration 491 return: -254.66731424439024
# Iteration 492 return: -298.06907117796953
# Iteration 493 return: -281.99100145183826
# Iteration 494 return: -302.0093260549074
# Iteration 495 return: -250.75072057550153
# Iteration 496 return: -250.429269400342
# Iteration 497 return: -261.86112340455304
# Iteration 498 return: -266.5972437270524
# Iteration 499 return: -311.965619636583

# %%
# collect saved results
import numpy as np
r1 = np.genfromtxt("InvertedPendulum_results.csv", delimiter=",")
all_results = [r1]
labels = ["REINFORCE"]

##############################################################
# Plot your Policy Gradient results below
##############################################################
import matplotlib.pyplot as plt
arrays = [np.array(x) for x in r1]
mean = [np.mean(k) for k in zip(*arrays)]
maximum = [np.max(k) for k in zip(*arrays) ]
minimum = [np.min(k) for k in zip(*arrays) ]

plt.plot(mean, label ="Average Reward")
plt.plot(maximum, label ="Maximum")
plt.plot(minimum, label ="Minimum")

plt.xlabel('Time')
plt.ylabel('Average Reward')
plt.title('Average Reward as a Function of Time')
plt.legend()

# %%
import gym 
env = gym.make("Pendulum-v0")
alg = REINFORCE(env, stochastic=True)
res= alg.train(learning_rate = 0.005, gamma = 0.95, num_iterations = 500, steps_per_iteration = 15000)
 
observation = env.reset()
for t in range(10000):
    env.render()
    action = alg.compute_action(observation.reshape(1,3))
    observation, reward, done, info = env.step(action)
    if done:
       
        break
env.close()
# Out:
# _____test-----
# <TimeLimit<PendulumEnv<Pendulum-v0>>>
# _____test-----
# printing output space
# printing output space
# 1
# printing output space end
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)
# Iteration 0 return: -1257.5860657593298
# Iteration 1 return: -1193.6577215555435
# Iteration 2 return: -1178.5868220660277
# Iteration 3 return: -1146.270281339677
# Iteration 4 return: -1136.9717755449067
# Iteration 5 return: -1166.2751333548097
# Iteration 6 return: -1084.8502052885706
# Iteration 7 return: -1140.2288921129486
# Iteration 8 return: -1114.6436771924327
# Iteration 9 return: -1060.033358241537
# Iteration 10 return: -1107.5160115265023
# Iteration 11 return: -1095.029044415164
# Iteration 12 return: -1127.1628097814787
# Iteration 13 return: -1160.2447617012829
# Iteration 14 return: -1129.2660431331396
# Iteration 15 return: -1167.2477233926331
# Iteration 16 return: -1118.71475215892
# Iteration 17 return: -1157.0309801507585
# Iteration 18 return: -1148.5980914057202
# Iteration 19 return: -1208.9912633646031
# Iteration 20 return: -1170.855377264445
# Iteration 21 return: -1154.9398455581597
# Iteration 22 return: -1150.5774648465247
# Iteration 23 return: -1146.4733779636833
# Iteration 24 return: -1096.658615065917
# Iteration 25 return: -1140.5328724504968
# Iteration 26 return: -1111.4078577662817
# Iteration 27 return: -1107.7904343110758
# Iteration 28 return: -1109.720814794749
# Iteration 29 return: -1059.312656940107
# Iteration 30 return: -1064.129956014664
# Iteration 31 return: -1070.8146592123776
# Iteration 32 return: -1038.970379803412
# Iteration 33 return: -1063.5622214514133
# Iteration 34 return: -1066.1511834309758
# Iteration 35 return: -1042.6713605656942
# Iteration 36 return: -1027.5899869995317
# Iteration 37 return: -1086.4456621002655
# Iteration 38 return: -1061.6935772831894
# Iteration 39 return: -1086.8788328283963
# Iteration 40 return: -1075.6065405407205
# Iteration 41 return: -1080.4031520330814
# Iteration 42 return: -1075.883106083859
# Iteration 43 return: -1051.1401216593601
# Iteration 44 return: -1080.0775282167658
# Iteration 45 return: -1081.33110072162
# Iteration 46 return: -1066.0245418515988
# Iteration 47 return: -1136.0301900424683
# Iteration 48 return: -1098.081383591458
# Iteration 49 return: -1095.798175288088
# Iteration 50 return: -1091.6934331672328
# Iteration 51 return: -1108.2442657491874
# Iteration 52 return: -1099.7424297611633
# Iteration 53 return: -1090.3081766128446
# Iteration 54 return: -1133.622795205315
# Iteration 55 return: -1097.3590379523237
# Iteration 56 return: -1067.0450633528083
# Iteration 57 return: -1029.1082350988406
# Iteration 58 return: -1048.8119964701764
# Iteration 59 return: -1041.5139654932575
# Iteration 60 return: -1001.1432768944217
# Iteration 61 return: -1085.5941867324275
# Iteration 62 return: -1018.7011208208852
# Iteration 63 return: -1068.8349164601352
# Iteration 64 return: -1056.2124299781738
# Iteration 65 return: -1064.4937158175806
# Iteration 66 return: -1043.1767563163148
# Iteration 67 return: -1039.6812070218225
# Iteration 68 return: -1017.395311872745
# Iteration 69 return: -1037.6279940196314
# Iteration 70 return: -1007.780044244475
# Iteration 71 return: -1003.3784158958107
# Iteration 72 return: -971.6113848521732
# Iteration 73 return: -987.1816872085134
# Iteration 74 return: -981.7782679283619
# Iteration 75 return: -967.4001798082182
# Iteration 76 return: -944.4386047149807
# Iteration 77 return: -985.1971913021058
# Iteration 78 return: -963.9729557432619
# Iteration 79 return: -1011.7208629252885
# Iteration 80 return: -931.0707377347769
# Iteration 81 return: -999.7696801333346
# Iteration 82 return: -980.0689309292069
# Iteration 83 return: -997.7524116938577
# Iteration 84 return: -1018.3937098860462
# Iteration 85 return: -1064.6614406030967
# Iteration 86 return: -1025.8219546408548
# Iteration 87 return: -1030.0576468948864
# Iteration 88 return: -1074.6194193183508
# Iteration 89 return: -1023.9186998170226
# Iteration 90 return: -955.7074968380915
# Iteration 91 return: -979.065424696765
# Iteration 92 return: -935.0278223063641
# Iteration 93 return: -940.7457325620662
# Iteration 94 return: -940.8278935836007
# Iteration 95 return: -908.472498186392
# Iteration 96 return: -947.0428342454741
# Iteration 97 return: -928.1075754146729
# Iteration 98 return: -902.5465271709463
# Iteration 99 return: -888.7013004467209
# Iteration 100 return: -872.5264325514987
# Iteration 101 return: -859.7702275591149
# Iteration 102 return: -875.559001288483
# Iteration 103 return: -875.8790193744376
# Iteration 104 return: -877.0502152920328
# Iteration 105 return: -878.0312477311523
# Iteration 106 return: -845.1340281677711
# Iteration 107 return: -884.0366504460899
# Iteration 108 return: -807.0257781521898
# Iteration 109 return: -833.8608145078148
# Iteration 110 return: -778.4089896045082
# Iteration 111 return: -784.0396692365055
# Iteration 112 return: -778.6413061449626
# Iteration 113 return: -750.5273714122463
# Iteration 114 return: -757.6284252979273
# Iteration 115 return: -790.6485318227432
# Iteration 116 return: -793.6145500897003
# Iteration 117 return: -857.3003219458265
# Iteration 118 return: -788.5272912190775
# Iteration 119 return: -760.5084752591195
# Iteration 120 return: -721.2055944449882
# Iteration 121 return: -757.4368069331049
# Iteration 122 return: -791.8532863154929
# Iteration 123 return: -721.9706328199835
# Iteration 124 return: -724.9478103487977
# Iteration 125 return: -764.7853771492963
# Iteration 126 return: -793.6826927347066
# Iteration 127 return: -760.5785257871596
# Iteration 128 return: -741.2657335278348
# Iteration 129 return: -743.3538398591033
# Iteration 130 return: -830.5402565083614
# Iteration 131 return: -847.1400372068955
# Iteration 132 return: -835.103202152473
# Iteration 133 return: -814.7619667399456
# Iteration 134 return: -742.2024633260155
# Iteration 135 return: -725.48906977966
# Iteration 136 return: -645.2007089494601
# Iteration 137 return: -644.1035662557694
# Iteration 138 return: -716.3963781518152
# Iteration 139 return: -782.4789116415801
# Iteration 140 return: -759.2538226761401
# Iteration 141 return: -765.7029339791169
# Iteration 142 return: -728.0876202727718
# Iteration 143 return: -600.2365431082955
# Iteration 144 return: -591.8063016067698
# Iteration 145 return: -596.6298109447487
# Iteration 146 return: -593.734665946764
# Iteration 147 return: -509.498751935674
# Iteration 148 return: -478.7395873419634
# Iteration 149 return: -493.8386845231654
# Iteration 150 return: -534.68020052065
# Iteration 151 return: -557.7709369912501
# Iteration 152 return: -560.3135343843259
# Iteration 153 return: -520.9779192902461
# Iteration 154 return: -568.9317513872185
# Iteration 155 return: -474.69937111200056
# Iteration 156 return: -482.1429085885047
# Iteration 157 return: -469.8959432807101
# Iteration 158 return: -483.75553860917563
# Iteration 159 return: -415.0737548038389
# Iteration 160 return: -341.7024275443962
# Iteration 161 return: -362.0294595424952
# Iteration 162 return: -367.44993189820957
# Iteration 163 return: -308.00476327412986
# Iteration 164 return: -330.6115812546105
# Iteration 165 return: -338.6561572856894
# Iteration 166 return: -278.83248117236917
# Iteration 167 return: -344.1466758632137
# Iteration 168 return: -301.2903083840318
# Iteration 169 return: -296.30862596070426
# Iteration 170 return: -340.6173744831301
# Iteration 171 return: -291.2851985810932
# Iteration 172 return: -330.2680523513203
# Iteration 173 return: -266.953618083222
# Iteration 174 return: -259.307535823523
# Iteration 175 return: -275.3969863812507
# Iteration 176 return: -303.58948193489863
# Iteration 177 return: -283.1685694152186
# Iteration 178 return: -281.4472050306247
# Iteration 179 return: -310.87255739412586
# Iteration 180 return: -271.5257733375492
# Iteration 181 return: -263.231069050194
# Iteration 182 return: -273.06442980917006
# Iteration 183 return: -264.2421364317048
# Iteration 184 return: -268.1102145667251
# Iteration 185 return: -278.72792506055924
# Iteration 186 return: -298.3132651903865
# Iteration 187 return: -296.47850234403126
# Iteration 188 return: -251.38487696333678
# Iteration 189 return: -292.80384711322677
# Iteration 190 return: -258.6301555942708
# Iteration 191 return: -311.0124784055808
# Iteration 192 return: -305.79411624671195
# Iteration 193 return: -294.3506872063436
# Iteration 194 return: -312.05843768430464
# Iteration 195 return: -291.291083636345
# Iteration 196 return: -296.9603425558394
# Iteration 197 return: -228.75760687755636
# Iteration 198 return: -331.50314289833034
# Iteration 199 return: -278.3768233650821
# Iteration 200 return: -246.58142295010228
# Iteration 201 return: -211.43163420686105
# Iteration 202 return: -268.3297342950131
# Iteration 203 return: -257.16194677043705
# Iteration 204 return: -281.12551512697274
# Iteration 205 return: -277.50504442213446
# Iteration 206 return: -256.71459676734605
# Iteration 207 return: -240.53039970554008
# Iteration 208 return: -255.3402485168927
# Iteration 209 return: -295.4554809994576
# Iteration 210 return: -266.63527998351407
# Iteration 211 return: -279.96701770761246
# Iteration 212 return: -287.46724080726113
# Iteration 213 return: -271.7447733504063
# Iteration 214 return: -241.66047004478926
# Iteration 215 return: -288.6131624200949
# Iteration 216 return: -302.1083283013797
# Iteration 217 return: -250.3937206314156
# Iteration 218 return: -276.63632867893006
# Iteration 219 return: -245.41869580772166
# Iteration 220 return: -271.6467475604983
# Iteration 221 return: -276.18774465083385
# Iteration 222 return: -283.21098507032366
# Iteration 223 return: -284.32237126244
# Iteration 224 return: -260.0897551536399
# Iteration 225 return: -230.02914962416028
# Iteration 226 return: -250.1017561867009
# Iteration 227 return: -268.00473934110516
# Iteration 228 return: -262.9113385017403
# Iteration 229 return: -252.59782291879316
# Iteration 230 return: -240.7483607423868
# Iteration 231 return: -228.6651543915471
# Iteration 232 return: -264.5326382576912
# Iteration 233 return: -320.94012537270635
# Iteration 234 return: -250.768261313143
# Iteration 235 return: -257.7209218690376
# Iteration 236 return: -227.93969507389372
# Iteration 237 return: -254.84170766880436
# Iteration 238 return: -257.46069150344215
# Iteration 239 return: -279.6587071342555
# Iteration 240 return: -254.91622601140844
# Iteration 241 return: -262.9987710035172
# Iteration 242 return: -238.47978837880942
# Iteration 243 return: -251.9916260028941
# Iteration 244 return: -243.33100718604027
# Iteration 245 return: -258.5171285094619
# Iteration 246 return: -263.2850347659599
# Iteration 247 return: -287.9969847355283
# Iteration 248 return: -285.4541613282774
# Iteration 249 return: -256.8578733041853
# Iteration 250 return: -295.47455470101454
# Iteration 251 return: -248.0705118520504
# Iteration 252 return: -280.2267911928707
# Iteration 253 return: -251.00862671297455
# Iteration 254 return: -260.9471913761884
# Iteration 255 return: -276.8043035723772
# Iteration 256 return: -229.2641042383084
# Iteration 257 return: -254.79629407278506
# Iteration 258 return: -267.517663588054
# Iteration 259 return: -240.37767918888537
# Iteration 260 return: -269.87517359875426
# Iteration 261 return: -285.5023077693928
# Iteration 262 return: -268.0608229152152
# Iteration 263 return: -248.18374482703376
# Iteration 264 return: -268.11709530834656
# Iteration 265 return: -244.53887638253505
# Iteration 266 return: -266.6271777743737
# Iteration 267 return: -272.2327990344714
# Iteration 268 return: -278.9124536802988
# Iteration 269 return: -275.7943240062469
# Iteration 270 return: -281.0358442135779
# Iteration 271 return: -274.0082564428421
# Iteration 272 return: -280.7001647997706
# Iteration 273 return: -254.98273207549985
# Iteration 274 return: -284.56870324688714
# Iteration 275 return: -281.88739645077777
# Iteration 276 return: -277.92871381687894
# Iteration 277 return: -246.95428421078657
# Iteration 278 return: -282.7043988103712
# Iteration 279 return: -251.03967771608538
# Iteration 280 return: -228.42585826975235
# Iteration 281 return: -246.99054252238182
# Iteration 282 return: -287.4108944211859
# Iteration 283 return: -252.02731873127797
# Iteration 284 return: -284.9514635757161
# Iteration 285 return: -252.29520307766896
# Iteration 286 return: -244.83754122904085
# Iteration 287 return: -272.8528344799239
# Iteration 288 return: -296.9647435715286
# Iteration 289 return: -260.65216565510985
# Iteration 290 return: -260.4898592290286
# Iteration 291 return: -277.43031488611
# Iteration 292 return: -281.9458908200922
# Iteration 293 return: -253.92324960134982
# Iteration 294 return: -270.17371758501713
# Iteration 295 return: -247.75225060871443
# Iteration 296 return: -274.8541310126565
# Iteration 297 return: -265.89719916245883
# Iteration 298 return: -239.51483874679485
# Iteration 299 return: -244.7646335024964
# Iteration 300 return: -235.97592369086166
# Iteration 301 return: -272.5841875333854
# Iteration 302 return: -262.3690794092115
# Iteration 303 return: -243.73749063354165
# Iteration 304 return: -288.6273516019196
# Iteration 305 return: -282.331851188126
# Iteration 306 return: -272.61247675606774
# Iteration 307 return: -250.06146199725453
# Iteration 308 return: -264.8591323053658
# Iteration 309 return: -256.1477124009325
# Iteration 310 return: -236.8708848301608
# Iteration 311 return: -262.57538984160345
# Iteration 312 return: -300.6240102900918
# Iteration 313 return: -243.13498813961442
# Iteration 314 return: -274.5019273101256
# Iteration 315 return: -260.0059625937074
# Iteration 316 return: -259.60077241151504
# Iteration 317 return: -299.0178300183378
# Iteration 318 return: -238.7274485727286
# Iteration 319 return: -261.1266939202527
# Iteration 320 return: -272.3020130980944
# Iteration 321 return: -252.82766598495743
# Iteration 322 return: -243.27195511623103
# Iteration 323 return: -239.9630346088609
# Iteration 324 return: -247.39233908833063
# Iteration 325 return: -263.0189638760688
# Iteration 326 return: -259.8535983014615
# Iteration 327 return: -249.80089873796197
# Iteration 328 return: -250.22705483841224
# Iteration 329 return: -242.33578981234768
# Iteration 330 return: -247.7523715694754
# Iteration 331 return: -239.37001671734518
# Iteration 332 return: -260.31479457690466
# Iteration 333 return: -253.16978913121693
# Iteration 334 return: -223.20893029668636
# Iteration 335 return: -271.17730827739547
# Iteration 336 return: -259.1585215606093
# Iteration 337 return: -278.4060030400339
# Iteration 338 return: -261.5265731263038
# Iteration 339 return: -255.8313766266311
# Iteration 340 return: -257.53183412089095
# Iteration 341 return: -249.4545542039374
# Iteration 342 return: -278.47140096979
# Iteration 343 return: -226.9110722202803
# Iteration 344 return: -239.05150171290865
# Iteration 345 return: -243.6624391194627
# Iteration 346 return: -245.26138226882176
# Iteration 347 return: -267.5099364316889
# Iteration 348 return: -238.1961386988381
# Iteration 349 return: -242.7016502295386
# Iteration 350 return: -272.51987720909636
# Iteration 351 return: -262.80361770169026
# Iteration 352 return: -286.9207747902001
# Iteration 353 return: -244.8560121254009
# Iteration 354 return: -246.42211423258811
# Iteration 355 return: -243.8513339503841
# Iteration 356 return: -229.76388905943628
# Iteration 357 return: -255.17197089031794
# Iteration 358 return: -276.85499660350206
# Iteration 359 return: -248.22962202932064
# Iteration 360 return: -237.49957823729503
# Iteration 361 return: -257.9559828545935
# Iteration 362 return: -263.3296397345141
# Iteration 363 return: -233.47868949610867
# Iteration 364 return: -270.56528815216666
# Iteration 365 return: -298.27279919903714
# Iteration 366 return: -260.50797617787725
# Iteration 367 return: -256.70546612390837
# Iteration 368 return: -298.7254728588974
# Iteration 369 return: -251.5042027831806
# Iteration 370 return: -268.87072793834005
# Iteration 371 return: -229.18088553042878
# Iteration 372 return: -250.3797912305134
# Iteration 373 return: -215.78627478292074
# Iteration 374 return: -291.72104603141963
# Iteration 375 return: -264.6128307104918
# Iteration 376 return: -277.7615067484861
# Iteration 377 return: -257.9599178641542
# Iteration 378 return: -250.53076992890206
# Iteration 379 return: -252.97781631890533
# Iteration 380 return: -260.85694503194486
# Iteration 381 return: -257.7520832817328
# Iteration 382 return: -289.6207928115727
# Iteration 383 return: -258.3139169307376
# Iteration 384 return: -262.17845362250705
# Iteration 385 return: -271.8658553361683
# Iteration 386 return: -255.4619197847908
# Iteration 387 return: -234.70941615952879
# Iteration 388 return: -263.02246228037274
# Iteration 389 return: -263.736972851109
# Iteration 390 return: -261.87813773893953
# Iteration 391 return: -283.08140486796765
# Iteration 392 return: -282.2829280598435
# Iteration 393 return: -246.7908907860244
# Iteration 394 return: -277.41717511883564
# Iteration 395 return: -267.14333788350706
# Iteration 396 return: -281.2110775820653
# Iteration 397 return: -273.14734234463805
# Iteration 398 return: -269.5115992405031
# Iteration 399 return: -271.4183203202418
# Iteration 400 return: -249.78961778544073
# Iteration 401 return: -256.9090386735741
# Iteration 402 return: -270.73811289383974
# Iteration 403 return: -276.85033232655536
# Iteration 404 return: -279.5858682809459
# Iteration 405 return: -294.47634470997997
# Iteration 406 return: -267.91600879172205
# Iteration 407 return: -314.51704289140616
# Iteration 408 return: -266.77842594750507
# Iteration 409 return: -258.01082288554267
# Iteration 410 return: -234.78235552631523
# Iteration 411 return: -263.2260990117142
# Iteration 412 return: -270.2987032318539
# Iteration 413 return: -301.84783981972544
# Iteration 414 return: -236.51875072191285
# Iteration 415 return: -225.6676351427524
# Iteration 416 return: -272.55336716306016
# Iteration 417 return: -247.84932288474587
# Iteration 418 return: -269.59755360516164
# Iteration 419 return: -294.4742164812271
# Iteration 420 return: -303.92622686409914
# Iteration 421 return: -242.164261234595
# Iteration 422 return: -293.4925408969786
# Iteration 423 return: -269.73330028389023
# Iteration 424 return: -285.5710111264415
# Iteration 425 return: -267.254935874542
# Iteration 426 return: -275.0457326600089
# Iteration 427 return: -270.75947015555033
# Iteration 428 return: -255.1569973905695
# Iteration 429 return: -269.82107237308054
# Iteration 430 return: -234.63056117231636
# Iteration 431 return: -240.05314693714254
# Iteration 432 return: -243.68049786605087
# Iteration 433 return: -312.26697532240144
# Iteration 434 return: -261.999780059201
# Iteration 435 return: -260.6154279126766
# Iteration 436 return: -286.7715946549508
# Iteration 437 return: -211.40821349389316
# Iteration 438 return: -276.989099392953
# Iteration 439 return: -270.6734304617212
# Iteration 440 return: -277.97131444043055
# Iteration 441 return: -254.33011477221396
# Iteration 442 return: -272.22498551400963
# Iteration 443 return: -239.14492845318037
# Iteration 444 return: -283.45758148218243
# Iteration 445 return: -231.77295834450658
# Iteration 446 return: -258.1086484400349
# Iteration 447 return: -213.99867217457455
# Iteration 448 return: -236.20569604659477
# Iteration 449 return: -230.09614490711755
# Iteration 450 return: -275.7590952802415
# Iteration 451 return: -241.56991143665033
# Iteration 452 return: -277.60921516194406
# Iteration 453 return: -257.7957769233608
# Iteration 454 return: -288.6860659179434
# Iteration 455 return: -276.4757336134288
# Iteration 456 return: -298.47990465003755
# Iteration 457 return: -254.75427072091722
# Iteration 458 return: -294.52546909926883
# Iteration 459 return: -269.02638003797546
# Iteration 460 return: -251.4313106610922
# Iteration 461 return: -285.323582562694
# Iteration 462 return: -272.278912722118
# Iteration 463 return: -241.6902091958758
# Iteration 464 return: -299.5953184622792
# Iteration 465 return: -285.8562320334832
# Iteration 466 return: -260.8638346993641
# Iteration 467 return: -264.7437621154928
# Iteration 468 return: -255.43183935232315
# Iteration 469 return: -279.58453883570564
# Iteration 470 return: -229.61633231720373
# Iteration 471 return: -275.6435126650311
# Iteration 472 return: -269.40363821261377
# Iteration 473 return: -257.6522936840442
# Iteration 474 return: -272.0520341373821
# Iteration 475 return: -238.87986392110452
# Iteration 476 return: -253.66138516979174
# Iteration 477 return: -232.73415263623275
# Iteration 478 return: -274.8157682555957
# Iteration 479 return: -232.6255609439235
# Iteration 480 return: -272.36797192493515
# Iteration 481 return: -302.3913203946145
# Iteration 482 return: -267.822726264867
# Iteration 483 return: -255.07090996432186
# Iteration 484 return: -271.19015876764354
# Iteration 485 return: -270.4810100028631
# Iteration 486 return: -273.83268698071464
# Iteration 487 return: -256.1173677781915
# Iteration 488 return: -272.76333787296886
# Iteration 489 return: -331.2188096747935
# Iteration 490 return: -276.12482053536473
# Iteration 491 return: -258.77267802282614
# Iteration 492 return: -234.56323913690284
# Iteration 493 return: -261.04065440417037
# Iteration 494 return: -255.03054887480482
# Iteration 495 return: -271.57441110176677
# Iteration 496 return: -244.25112373862154
# Iteration 497 return: -237.3656296844362
# Iteration 498 return: -268.3228495289175
# Iteration 499 return: -259.9156803302978
# Done

# %%
obs = env.reset()
done = False
while (not done):
    env.render()
    action = alg.compute_action(observation.reshape(1,3))
    observation, reward, done, info= env.step(action)
env.close()
